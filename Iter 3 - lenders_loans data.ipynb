# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
import graphlab as gl
import csv
import collections
import datetime
from graphlab.toolkits.model_parameter_search import model_parameter_search
gl.canvas.set_target('ipynb')

# %%
client = MongoClient()
kiva = client.kiva
mongo_loans = kiva.loans
mongo_lenders_loans = kiva.lenders_loans

# %% [markdown]
# ##Feature Engineering
# This iteration will take into account several simple features: **activity, loan_amount, country, posted_date, sector**.

# %% [markdown]
# ###Create lender loan matrix

# %%
# get loans_lenders
cursor_lenders_loans = mongo_lenders_loans.find({}, {'_id':0}).sort('lender_id', 1).limit(100000)
sample_lenders_loans = pd.DataFrame(list(cursor_lenders_loans))
sample_lenders_loans.dropna(inplace=True)

# %%
# create lender-loan pairs
with open('data/lenders_loans_100000.csv', 'w') as f:
    wr = csv.writer(f, delimiter=',')
    for r in sample_lenders_loans.iterrows():
        for l in r[1]['loan_ids']:
            wr.writerow([r[1]['lender_id'], l])

# %%
sf = gl.SFrame.read_csv('data/lenders_loans_100000.csv', header=False, delimiter=',', verbose=False)
sf.rename({'X1':'lender_id', 'X2':'loan_id'})
sf.sort('loan_id')
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-2743 - Server binary: /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1425765020.log
# [INFO] GraphLab Server Version: 1.3.0
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /Users/yulizhou/Documents/Projects/zipfian/Kipfian/data/lenders_loans_100000.csv
# PROGRESS: Parsing completed. Parsed 1218194 lines in 0.80929 secs.
# Columns:
# 	lender_id	str
# 	loan_id	int
#
# Rows: 1218194
#
# Data:
# +----------------+---------+
# |   lender_id    | loan_id |
# +----------------+---------+
# | NkInteractClub |  280242 |
# |     am3914     |  280741 |
# |    ake8008     |  280758 |
# |  alistair8793  |  280758 |
# |  barbara4752   |  280766 |
# |   adrian9794   |  280766 |
# |     am3914     |  280766 |
# | aaron83574977  |  280766 |
# |  alistair8793  |  280776 |
# |   andrew4225   |  280781 |
# |      ...       |   ...   |
# +----------------+---------+
# [1218194 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ###Create side features

# %%
# start getting features

# get rid of loans in lender_loans but not in loans
feat_loan_id = sf['loan_id'].unique().sort()
ids = list(feat_loan_id)
temp_cursor = mongo_loans.find({'id': {'$in': ids}}, {'id': 1, '_id': 0})
loans_ids_exists = list(temp_cursor)
loans_ids_exists = sorted([l['id'] for l in loans_ids_exists])
diff_ids = set(ids) - set(loans_ids_exists)
sf['loan_id'] = sf['loan_id'].apply(lambda x: x if x not in diff_ids else None)
sf = sf.dropna('loan_id')

# %%
c=mongo_loans.find({'id': {'$in': loans_ids_exists}}, 
                   {'id': 1, 'activity': 1, 'loan_amount': 1, 'sector': 1, 'location.country':1, 'posted_date': 1, '_id':0})\
                    .sort('id', 1)
raw_features = gl.SFrame(list(c))

# %%
raw_features['loan_id'] = raw_features.apply(lambda x: x['X1']['id']).astype(str)

# %%
raw_features['activity'] = raw_features.apply(lambda x: x['X1']['activity'])

# %%
# get sector
raw_features['sector'] = raw_features.apply(lambda x: x['X1']['sector'])

# %%
# get loan_amount
raw_features['loan_amount'] = raw_features.apply(lambda x: x['X1']['loan_amount'])

# %%
# get country
raw_features['country'] = raw_features.apply(lambda x: x['X1']['location']['country'])

# %%
# get posted_date
raw_features['day_of_year'] = raw_features.apply(
    lambda x: pd.to_datetime(x['X1']['posted_date'], format='%Y-%m-%dT%H:%M:%SZ').timetuple().tm_yday)

# %%
# drop unused columns
raw_features.remove_column('X1')
# Out:
# Columns:
# 	loan_id	str
# 	activity	str
# 	sector	str
# 	loan_amount	int
# 	country	str
# 	day_of_year	int
#
# Rows: 401765
#
# Data:
# +---------+-----------------------+-------------+-------------+--------------+
# | loan_id |        activity       |    sector   | loan_amount |   country    |
# +---------+-----------------------+-------------+-------------+--------------+
# |  280242 |        Services       |   Services  |     725     |     Peru     |
# |  280741 |     General Store     |    Retail   |     350     | Philippines  |
# |  280758 |       Livestock       | Agriculture |     600     | Philippines  |
# |  280766 |     General Store     |    Retail   |     575     | Philippines  |
# |  280776 |        Poultry        | Agriculture |     400     | Philippines  |
# |  280781 |      Fish Selling     |     Food    |     475     | Philippines  |
# |  280785 | Food Production/Sales |     Food    |     350     | Philippines  |
# |  280872 |      Fish Selling     |     Food    |     700     |  Nicaragua   |
# |  281685 |        Pharmacy       |    Health   |     700     | Sierra Leone |
# |  281858 |     General Store     |    Retail   |     2700    | Philippines  |
# +---------+-----------------------+-------------+-------------+--------------+
# +-------------+
# | day_of_year |
# +-------------+
# |     102     |
# |     110     |
# |     110     |
# |     110     |
# |     110     |
# |     110     |
# |     110     |
# |     103     |
# |     112     |
# |     110     |
# |     ...     |
# +-------------+
# [401765 rows x 6 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ## Train the model

# %%
# convert features into SFrame
loan_feature = gl.SFrame({'loan_id': list(raw_features['loan_id']), 
                          'activity': list(raw_features['activity']), 
                          'sector': list(raw_features['sector']), 
                          'loan_amount': list(raw_features['loan_amount']), 
                          'country': list(raw_features['country']), 
                          'day_of_year': list(raw_features['day_of_year'])})

# %%
loan_feature
# Out:
# Columns:
# 	activity	str
# 	country	str
# 	day_of_year	int
# 	loan_amount	int
# 	loan_id	str
# 	sector	str
#
# Rows: 401765
#
# Data:
# +-----------------------+--------------+-------------+-------------+---------+
# |        activity       |   country    | day_of_year | loan_amount | loan_id |
# +-----------------------+--------------+-------------+-------------+---------+
# |        Services       |     Peru     |     102     |     725     |  280242 |
# |     General Store     | Philippines  |     110     |     350     |  280741 |
# |       Livestock       | Philippines  |     110     |     600     |  280758 |
# |     General Store     | Philippines  |     110     |     575     |  280766 |
# |        Poultry        | Philippines  |     110     |     400     |  280776 |
# |      Fish Selling     | Philippines  |     110     |     475     |  280781 |
# | Food Production/Sales | Philippines  |     110     |     350     |  280785 |
# |      Fish Selling     |  Nicaragua   |     103     |     700     |  280872 |
# |        Pharmacy       | Sierra Leone |     112     |     700     |  281685 |
# |     General Store     | Philippines  |     110     |     2700    |  281858 |
# +-----------------------+--------------+-------------+-------------+---------+
# +-------------+
# |    sector   |
# +-------------+
# |   Services  |
# |    Retail   |
# | Agriculture |
# |    Retail   |
# | Agriculture |
# |     Food    |
# |     Food    |
# |     Food    |
# |    Health   |
# |    Retail   |
# |     ...     |
# +-------------+
# [401765 rows x 6 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
# split train test
train, test = gl.recommender.util.random_split_by_user(sf, user_id='lender_id', item_id='loan_id', item_test_proportion=0.2)

# %%
# Train the model
models = []
regs = [0.1, 0.01, 0.001]
num_factors = range(2, 5)
for n in num_factors:
    for r in regs:
        m = gl.recommender.ranking_factorization_recommender.create(train,
                                                                    user_id='lender_id', 
                                                                    item_id='loan_id',
                                                                    item_data=loan_feature,
                                                                    num_factors=n,
                                                                    regularization=r, 
                                                                    binary_target=True, 
                                                                    verbose=True)
        models.append(m)
# Out:
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1214724 observations with 86321 users and 803205 items.
# PROGRESS:     Data prepared in: 1.68393s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 2        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.1      |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151840 / 1214724 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.000606562       | 1.38133                                  |
# PROGRESS: | 1       | 0.000303281       | 1.38378                                  |
# PROGRESS: | 2       | 0.00015164        | 1.38503                                  |
# PROGRESS: | 3       | 7.58202e-05       | 1.38569                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.000606562       | 1.38133                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 377us        | 1.3883            | 0.693153                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.27s        | 1.38036           | 0.692626                          | 0.000606562 |
# PROGRESS: | 2       | 2.46s        | 1.37888           | 0.692224                          | 0.000606562 |
# PROGRESS: | 3       | 3.61s        | 1.37723           | 0.691964                          | 0.000606562 |
# PROGRESS: | 4       | 4.72s        | 1.37592           | 0.691738                          | 0.000606562 |
# PROGRESS: | 5       | 5.85s        | 1.37485           | 0.691537                          | 0.000606562 |
# PROGRESS: | 6       | 7.04s        | 1.37387           | 0.691345                          | 0.000606562 |
# PROGRESS: | 7       | 8.23s        | 1.37299           | 0.691161                          | 0.000606562 |
# PROGRESS: | 8       | 9.40s        | 1.37224           | 0.690985                          | 0.000606562 |
# PROGRESS: | 9       | 10.65s       | 1.37151           | 0.69081                           | 0.000606562 |
# PROGRESS: | 10      | 11.91s       | 1.37093           | 0.69064                           | 0.000606562 |
# PROGRESS: | 11      | 13.05s       | 1.37038           | 0.690476                          | 0.000606562 |
# PROGRESS: | 12      | 14.18s       | 1.36969           | 0.690321                          | 0.000606562 |
# PROGRESS: | 13      | 15.28s       | 1.36918           | 0.690165                          | 0.000606562 |
# PROGRESS: | 14      | 16.36s       | 1.3687            | 0.690012                          | 0.000606562 |
# PROGRESS: | 15      | 17.52s       | 1.36826           | 0.689862                          | 0.000606562 |
# PROGRESS: | 16      | 18.74s       | 1.36784           | 0.689716                          | 0.000606562 |
# PROGRESS: | 20      | 23.63s       | 1.33728           | 0.660001                          | 0.00606562  |
# PROGRESS: | 21      | 24.75s       | 1.33714           | 0.659845                          | 0.00606562  |
# PROGRESS: | 22      | 25.88s       | 1.33692           | 0.659694                          | 0.00606562  |
# PROGRESS: | 23      | 27.03s       | 1.33666           | 0.659499                          | 0.00606562  |
# PROGRESS: | 24      | 28.14s       | 1.33663           | 0.659377                          | 0.00606562  |
# PROGRESS: | 25      | 29.24s       | 1.33626           | 0.659257                          | 0.00606562  |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.3362
# PROGRESS:        Final training Predictive Error: 0.65904
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1214724 observations with 86321 users and 803205 items.
# PROGRESS:     Data prepared in: 1.76097s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 2        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.001    |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151840 / 1214724 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.0606562         | 1.30037                                  |
# PROGRESS: | 1       | 0.0303281         | 1.32048                                  |
# PROGRESS: | 2       | 0.015164          | 1.33489                                  |
# PROGRESS: | 3       | 0.00758202        | 1.34918                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.0606562         | 1.30037                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 355us        | 1.38663           | 0.693155                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.12s        | 1.36002           | 0.641201                          | 0.0606562   |
# PROGRESS: | 2       | 2.21s        | 1.34215           | 0.661398                          | 0.0606562   |
# PROGRESS: | 3       | 3.29s        | 1.33541           | 0.65645                           | 0.0606562   |
# PROGRESS: | 4       | 4.36s        | 1.3315            | 0.655668                          | 0.0606562   |
# PROGRESS: | 5       | 5.47s        | 1.3289            | 0.654367                          | 0.0606562   |
# PROGRESS: | 6       | 6.55s        | 1.327             | 0.653836                          | 0.0606562   |
# PROGRESS: | 7       | 7.64s        | 1.32567           | 0.65384                           | 0.0606562   |
# PROGRESS: | 8       | 8.73s        | 1.32443           | 0.652701                          | 0.0606562   |
# PROGRESS: | 9       | 9.80s        | 1.32328           | 0.652566                          | 0.0606562   |
# PROGRESS: | 10      | 10.88s       | 1.32297           | 0.652247                          | 0.0606562   |
# PROGRESS: | 11      | 11.98s       | 1.32263           | 0.652344                          | 0.0606562   |
# PROGRESS: | 12      | 13.15s       | 1.321             | 0.651646                          | 0.0606562   |
# PROGRESS: | 13      | 14.26s       | 1.32035           | 0.651348                          | 0.0606562   |
# PROGRESS: | 14      | 15.35s       | 1.31993           | 0.651234                          | 0.0606562   |
# PROGRESS: | 15      | 16.47s       | 1.31974           | 0.650946                          | 0.0606562   |
# PROGRESS: | 16      | 17.56s       | 1.31928           | 0.650849                          | 0.0606562   |
# PROGRESS: | 17      | 18.75s       | 1.31903           | 0.650627                          | 0.0606562   |
# PROGRESS: | 18      | 19.84s       | 1.31815           | 0.650292                          | 0.0606562   |
# PROGRESS: | 19      | 20.99s       | 1.31839           | 0.650407                          | 0.0606562   |
# PROGRESS: | 20      | 22.09s       | 1.31777           | 0.650288                          | 0.0606562   |
# PROGRESS: | 21      | 23.17s       | 1.31788           | 0.650117                          | 0.0606562   |
# PROGRESS: | 22      | 24.30s       | 1.31761           | 0.650081                          | 0.0606562   |
# PROGRESS: | 23      | 25.41s       | 1.31714           | 0.650042                          | 0.0606562   |
# PROGRESS: | 24      | 26.62s       | 1.3169            | 0.649821                          | 0.0606562   |
# PROGRESS: | 25      | 27.76s       | 1.31675           | 0.649735                          | 0.0606562   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1

# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.36431
# PROGRESS:        Final training Predictive Error: 0.688399
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1214724 observations with 86321 users and 803205 items.
# PROGRESS:     Data prepared in: 2.10223s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 3        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.01     |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151840 / 1214724 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.00606562        | 1.35438                                  |
# PROGRESS: | 1       | 0.00303281        | 1.3661                                   |
# PROGRESS: | 2       | 0.0015164         | 1.37501                                  |
# PROGRESS: | 3       | 0.000758202       | 1.38028                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.00606562        | 1.35438                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 549us        | 1.38677           | 0.693136                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.59s        | 1.3543            | 0.674189                          | 0.00606562  |
# PROGRESS: | 2       | 3.14s        | 1.35054           | 0.671276                          | 0.00606562  |
# PROGRESS: | 3       | 4.51s        | 1.34716           | 0.669307                          | 0.00606562  |
# PROGRESS: | 4       | 5.97s        | 1.34501           | 0.667748                          | 0.00606562  |
# PROGRESS: | 5       | 7.47s        | 1.34397           | 0.666482                          | 0.00606562  |
# PROGRESS: | 6       | 8.84s        | 1.34264           | 0.665505                          | 0.00606562  |
# PROGRESS: | 7       | 10.20s       | 1.34181           | 0.664633                          | 0.00606562  |
# PROGRESS: | 8       | 11.61s       | 1.34127           | 0.663905                          | 0.00606562  |
# PROGRESS: | 9       | 13.03s       | 1.34059           | 0.663303                          | 0.00606562  |
# PROGRESS: | 10      | 14.48s       | 1.34042           | 0.662726                          | 0.00606562  |
# PROGRESS: | 11      | 15.96s       | 1.34002           | 0.66229                           | 0.00606562  |
# PROGRESS: | 12      | 17.48s       | 1.33935           | 0.661867                          | 0.00606562  |
# PROGRESS: | 13      | 18.92s       | 1.33905           | 0.661495                          | 0.00606562  |
# PROGRESS: | 14      | 20.33s       | 1.33878           | 0.661199                          | 0.00606562  |
# PROGRESS: | 15      | 21.84s       | 1.33862           | 0.66094                           | 0.00606562  |
# PROGRESS: | 16      | 23.33s       | 1.33833           | 0.660715                          | 0.00606562  |
# PROGRESS: | 17      | 24.82s       | 1.33807           | 0.660505                          | 0.00606562  |
# PROGRESS: | 18      | 26.20s       | 1.33758           | 0.660282                          | 0.00606562  |
# PROGRESS: | 19      | 27.68s       | 1.33755           | 0.660079                          | 0.00606562  |
# PROGRESS: | 20      | 29.07s       | 1.33729           | 0.659914                          | 0.00606562  |
# PROGRESS: | 21      | 30.48s       | 1.33733           | 0.659753                          | 0.00606562  |
# PROGRESS: | 22      | 31.89s       | 1.33699           | 0.659599                          | 0.00606562  |
# PROGRESS: | 23      | 33.29s       | 1.33669           | 0.659433                          | 0.00606562  |
# PROGRESS: | 24      | 34.66s       | 1.33664           | 0.659275                          | 0.00606562  |
# PROGRESS: | 25      | 36.16s       | 1.33629           | 0.659161                          | 0.00606562  |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.33626
# PROGRESS:        Final training Predictive Error: 0.658924
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1214724 observations with 86321 users and 803205 items.
# PROGRESS:     Data prepared in: 2.02793s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 3        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.001    |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151840 / 1214724 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.0606562         | 1.30954                                  |
# PROGRESS: | 1       | 0.0303281         | 1.32501                                  |
# PROGRESS: | 2       | 0.015164          | 1.33685                                  |
# PROGRESS: | 3       | 0.00758202        | 1.35115                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.0606562         | 1.30954                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 364us        | 1.38661           | 0.693144                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.46s        | 1.38178           | 0.642983                          | 0.0606562   |
# PROGRESS: | 2       | 2.85s        | 1.34314           | 0.661199                          | 0.0606562   |
# PROGRESS: | 3       | 4.23s        | 1.33584           | 0.656026                          | 0.0606562   |
# PROGRESS: | 4       | 5.59s        | 1.33189           | 0.6557                            | 0.0606562   |
# PROGRESS: | 5       | 6.99s        | 1.32931           | 0.654242                          | 0.0606562   |
# PROGRESS: | 6       | 8.39s        | 1.32767           | 0.653517                          | 0.0606562   |
# PROGRESS: | 7       | 9.78s        | 1.32593           | 0.653675                          | 0.0606562   |
# PROGRESS: | 8       | 11.21s       | 1.32481           | 0.652412                          | 0.0606562   |
# PROGRESS: | 9       | 12.58s       | 1.32345           | 0.652241                          | 0.0606562   |
# PROGRESS: | 10      | 13.97s       | 1.32277           | 0.651987                          | 0.0606562   |
# PROGRESS: | 11      | 15.37s       | 1.32251           | 0.652117                          | 0.0606562   |
# PROGRESS: | 12      | 16.76s       | 1.32118           | 0.65144                           | 0.0606562   |
# PROGRESS: | 13      | 18.19s       | 1.32075           | 0.651105                          | 0.0606562   |
# PROGRESS: | 14      | 19.57s       | 1.31994           | 0.651221                          | 0.0606562   |
# PROGRESS: | 15      | 20.98s       | 1.31976           | 0.65106                           | 0.0606562   |
# PROGRESS: | 16      | 22.42s       | 1.31958           | 0.650701                          | 0.0606562   |
# PROGRESS: | 17      | 23.88s       | 1.31919           | 0.650538                          | 0.0606562   |
# PROGRESS: | 18      | 25.29s       | 1.31829           | 0.650296                          | 0.0606562   |
# PROGRESS: | 19      | 26.74s       | 1.31842           | 0.65026                           | 0.0606562   |
# PROGRESS: | 20      | 28.15s       | 1.31836           | 0.650142                          | 0.0606562   |
# PROGRESS: | 21      | 29.54s       | 1.31773           | 0.650128                          | 0.0606562   |
# PROGRESS: | 22      | 30.95s       | 1.3174            | 0.650133                          | 0.0606562   |
# PROGRESS: | 23      | 32.38s       | 1.31723           | 0.65003                           | 0.0606562   |
# PROGRESS: | 24      | 33.81s       | 1.3171            | 0.649808                          | 0.0606562   |
# PROGRESS: | 25      | 35.22s       | 1.31668           | 0.649687                          | 0.0606562   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.31489
# PROGRESS:        Final training Predictive Error: 0.647989
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1214724 observations with 86321 users and 803205 items.
# PROGRESS:     Data prepared in: 2.02322s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 4        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.1      |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151840 / 1214724 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.000606562       | 1.38159                                  |
# PROGRESS: | 1       | 0.000303281       | 1.38385                                  |
# PROGRESS: | 2       | 0.00015164        | 1.38507                                  |
# PROGRESS: | 3       | 7.58202e-05       | 1.38571                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0
          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.34s        | 1.35538           | 0.669782                          | 0.00606562  |
# PROGRESS: | 2       | 2.64s        | 1.35035           | 0.668768                          | 0.00606562  |
# PROGRESS: | 3       | 3.94s        | 1.34713           | 0.667619                          | 0.00606562  |
# PROGRESS: | 4       | 5.21s        | 1.34507           | 0.666525                          | 0.00606562  |
# PROGRESS: | 5       | 6.56s        | 1.34378           | 0.665539                          | 0.00606562  |
# PROGRESS: | 6       | 7.89s        | 1.34257           | 0.664646                          | 0.00606562  |
# PROGRESS: | 7       | 9.24s        | 1.34184           | 0.663965                          | 0.00606562  |
# PROGRESS: | 8       | 10.58s       | 1.3413            | 0.66337                           | 0.00606562  |
# PROGRESS: | 9       | 11.91s       | 1.34063           | 0.662817                          | 0.00606562  |
# PROGRESS: | 10      | 13.23s       | 1.34041           | 0.66232                           | 0.00606562  |
# PROGRESS: | 11      | 14.56s       | 1.34006           | 0.661954                          | 0.00606562  |
# PROGRESS: | 12      | 16.07s       | 1.33936           | 0.661572                          | 0.00606562  |
# PROGRESS: | 13      | 17.46s       | 1.33909           | 0.661265                          | 0.00606562  |
# PROGRESS: | 14      | 18.77s       | 1.33881           | 0.660966                          | 0.00606562  |
# PROGRESS: | 15      | 20.14s       | 1.33871           | 0.660687                          | 0.00606562  |
# PROGRESS: | 16      | 21.47s       | 1.33831           | 0.66047                           | 0.00606562  |
# PROGRESS: | 17      | 22.77s       | 1.33803           | 0.660254                          | 0.00606562  |
# PROGRESS: | 18      | 24.07s       | 1.33763           | 0.660015                          | 0.00606562  |
# PROGRESS: | 19      | 25.40s       | 1.33766           | 0.659835                          | 0.00606562  |
# PROGRESS: | 20      | 26.79s       | 1.33731           | 0.659675                          | 0.00606562  |
# PROGRESS: | 21      | 28.15s       | 1.33726           | 0.659508                          | 0.00606562  |
# PROGRESS: | 22      | 29.51s       | 1.33702           | 0.659375                          | 0.00606562  |
# PROGRESS: | 23      | 30.84s       | 1.33668           | 0.659222                          | 0.00606562  |
# PROGRESS: | 24      | 32.21s       | 1.33671           | 0.659113                          | 0.00606562  |
# PROGRESS: | 25      | 33.60s       | 1.33635           | 0.658985                          | 0.00606562  |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.33625
# PROGRESS:        Final training Predictive Error: 0.65877
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1214724 observations with 86321 users and 803205 items.
# PROGRESS:     Data prepared in: 2.11022s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 4        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.001    |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151840 / 1214724 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.0606562         | 1.31722                                  |
# PROGRESS: | 1       | 0.0303281         | 1.32943                                  |
# PROGRESS: | 2       | 0.015164          | 1.33892                                  |
# PROGRESS: | 3       | 0.00758202        | 1.35196                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.0606562         | 1.31722                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 349us        | 1.38664           | 0.693147                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.32s        | 1.4188            | 0.660841                          | 0.0606562   |
# PROGRESS: | 2       | 2.63s        | 1.34343           | 0.659225                          | 0.0606562   |
# PROGRESS: | 3       | 3.91s        | 1.33666           | 0.656613                          | 0.0606562   |
# PROGRESS: | 4       | 5.19s        | 1.33308           | 0.655579                          | 0.0606562   |
# PROGRESS: | 5       | 6.52s        | 1.33083           | 0.654442                          | 0.0606562   |
# PROGRESS: | 6       | 7.92s        | 1.32781           | 0.653685                          | 0.0606562   |
# PROGRESS: | 7       | 9.22s        | 1.32681           | 0.653454                          | 0.0606562   |
# PROGRESS: | 8       | 10.51s       | 1.3251            | 0.652917                          | 0.0606562   |
# PROGRESS: | 9       | 11.79s       | 1.3241            | 0.652347                          | 0.0606562   |
# PROGRESS: | 10      | 13.27s       | 1.32421           | 0.652091                          | 0.0606562   |
# PROGRESS: | 11      | 14.59s       | 1.3233            | 0.651905                          | 0.0606562   |
# PROGRESS: | 12      | 15.90s       | 1.32156           | 0.651516                          | 0.0606562   |
# PROGRESS: | 13      | 17.18s       | 1.32123           | 0.65136                           | 0.0606562   |
# PROGRESS: | 14      | 18.46s       | 1.32028           | 0.651197                          | 0.0606562   |
# PROGRESS: | 15      | 19.77s       | 1.31972           | 0.651003                          | 0.0606562   |
# PROGRESS: | 16      | 21.06s       | 1.31936           | 0.650905                          | 0.0606562   |
# PROGRESS: | 17      | 22.41s       | 1.32028           | 0.650453                          | 0.0606562   |
# PROGRESS: | 18      | 23.69s       | 1.3183            | 0.650366                          | 0.0606562   |
# PROGRESS: | 19      | 24.98s       | 1.31822           | 0.65025                           | 0.0606562   |
# PROGRESS: | 20      | 26.29s       | 1.31847           | 0.650127                          | 0.0606562   |
# PROGRESS: | 21      | 27.57s       | 1.31775           | 0.649919                          | 0.0606562   |
# PROGRESS: | 22      | 28.86s       | 1.31779           | 0.649893                          | 0.0606562   |
# PROGRESS: | 23      | 30.14s       | 1.31719           | 0.649776                          | 0.0606562   |
# PROGRESS: | 24      | 31.45s       | 1.31703           | 0.649916                          | 0.0606562   |
# PROGRESS: | 25      | 32.73s       | 1.31661           | 0.649673                          | 0.0606562   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.31491
# PROGRESS:        Final training Predictive Error: 0.648369
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.

# %%
# compare models
for i, m in enumerate(models):
    print '='*100
    print 'MODEL ', i
    m.evaluate(test, metric='precision_recall')
# Out:
# ====================================================================================================
# MODEL  0
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  1
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  2
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  3
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  4
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  5
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  6
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  7
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  8
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+------------------+
# | cutoff |   mean_precision  |   mean_recall    |
# +--------+-------------------+------------------+
# |   5    |  0.00111317254174 | 0.00126998851489 |
# |   10   | 0.000556586270872 | 0.00126998851489 |
# |   15   | 0.000371057513915 | 0.00126998851489 |
# +--------+-------------------+------------------+
# [3 rows x 3 columns]

# %%
train.groupby(key_columns='lender_id', operations={'count': gl.aggregate.COUNT()}).sort('count', ascending=False)
# Out:
# Columns:
# 	lender_id	str
# 	count	int
#
# Rows: 86321
#
# Data:
# +---------------+-------+
# |   lender_id   | count |
# +---------------+-------+
# |  barbara5610  | 20782 |
# |  amirali5409  | 17872 |
# | aaron83574977 | 10202 |
# |   barrie7327  |  8346 |
# | andrewhoffman |  6976 |
# |   andrew5306  |  5694 |
# |     JY1024    |  5196 |
# |   anon23456   |  5106 |
# |    ali9555    |  4912 |
# | FrequentMiler |  4887 |
# |      ...      |  ...  |
# +---------------+-------+
# [86321 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.
