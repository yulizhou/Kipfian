# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
import graphlab as gl
import csv
import collections
import datetime
from graphlab.toolkits.model_parameter_search import model_parameter_search
gl.canvas.set_target('ipynb')

# %%
client = MongoClient()
kiva = client.kiva
mongo_loans = kiva.loans
mongo_lenders_loans = kiva.lenders_loans

# %% [markdown]
# ##Feature Engineering
# This iteration will take into account several simple features: **activity, loan_amount, country, posted_date, sector**.

# %% [markdown]
# ###Create lender loan matrix

# %%
# get loans_lenders
cursor_lenders_loans = mongo_lenders_loans.find({}, {'_id':0}).sort('lender_id', 1).limit(100000)
sample_lenders_loans = pd.DataFrame(list(cursor_lenders_loans))
sample_lenders_loans.dropna(inplace=True)

# %%
# create lender-loan pairs
with open('data/lenders_loans_100000.csv', 'w') as f:
    wr = csv.writer(f, delimiter=',')
    for r in sample_lenders_loans.iterrows():
        for l in r[1]['loan_ids']:
            wr.writerow([r[1]['lender_id'], l])

# %%
sf = gl.SFrame.read_csv('data/lenders_loans_100000.csv', header=False, delimiter=',', verbose=False)
sf.rename({'X1':'lender_id', 'X2':'loan_id'})
sf.sort('loan_id')
# Out:
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /Users/yulizhou/Documents/Projects/zipfian/Kipfian/data/lenders_loans_100000.csv
# PROGRESS: Parsing completed. Parsed 1218194 lines in 0.849273 secs.
# Columns:
# 	lender_id	str
# 	loan_id	int
#
# Rows: 1218194
#
# Data:
# +----------------+---------+
# |   lender_id    | loan_id |
# +----------------+---------+
# | NkInteractClub |  280242 |
# |     am3914     |  280741 |
# |    ake8008     |  280758 |
# |  alistair8793  |  280758 |
# |  barbara4752   |  280766 |
# |   adrian9794   |  280766 |
# |     am3914     |  280766 |
# | aaron83574977  |  280766 |
# |  alistair8793  |  280776 |
# |   andrew4225   |  280781 |
# |      ...       |   ...   |
# +----------------+---------+
# [1218194 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ###Create side features

# %%
# start getting features

# get rid of loans in lender_loans but not in loans
feat_loan_id = sf['loan_id'].unique().sort()
ids = list(feat_loan_id)
temp_cursor = mongo_loans.find({'id': {'$in': ids}}, {'id': 1, '_id': 0})
loans_ids_exists = list(temp_cursor)
loans_ids_exists = sorted([l['id'] for l in loans_ids_exists])
diff_ids = set(ids) - set(loans_ids_exists)
sf['loan_id'] = sf['loan_id'].apply(lambda x: x if x not in diff_ids else None)
sf = sf.dropna('loan_id')

# %%
c=mongo_loans.find({'id': {'$in': loans_ids_exists}}, 
                   {'id': 1, 'activity': 1, 'loan_amount': 1, 'sector': 1, 'location.country':1, 'posted_date': 1, '_id':0})\
                    .sort('id', 1)
raw_features = gl.SFrame(list(c))

# %%
raw_features['loan_id'] = raw_features.apply(lambda x: x['X1']['id']).astype(str)

# %%
raw_features['activity'] = raw_features.apply(lambda x: x['X1']['activity'])

# %%
# get sector
raw_features['sector'] = raw_features.apply(lambda x: x['X1']['sector'])

# %%
# get loan_amount
raw_features['loan_amount'] = raw_features.apply(lambda x: x['X1']['loan_amount'])

# %%
# get country
raw_features['country'] = raw_features.apply(lambda x: x['X1']['location']['country'])

# %%
# get posted_date
raw_features['day_of_year'] = raw_features.apply(
    lambda x: pd.to_datetime(x['X1']['posted_date'], format='%Y-%m-%dT%H:%M:%SZ').timetuple().tm_yday)

# %%
# drop unused columns
raw_features.remove_column('X1')
# Out:
# Columns:
# 	loan_id	str
# 	activity	str
# 	sector	str
# 	loan_amount	int
# 	country	str
# 	day_of_year	int
#
# Rows: 401765
#
# Data:
# +---------+-----------------------+-------------+-------------+--------------+
# | loan_id |        activity       |    sector   | loan_amount |   country    |
# +---------+-----------------------+-------------+-------------+--------------+
# |  280242 |        Services       |   Services  |     725     |     Peru     |
# |  280741 |     General Store     |    Retail   |     350     | Philippines  |
# |  280758 |       Livestock       | Agriculture |     600     | Philippines  |
# |  280766 |     General Store     |    Retail   |     575     | Philippines  |
# |  280776 |        Poultry        | Agriculture |     400     | Philippines  |
# |  280781 |      Fish Selling     |     Food    |     475     | Philippines  |
# |  280785 | Food Production/Sales |     Food    |     350     | Philippines  |
# |  280872 |      Fish Selling     |     Food    |     700     |  Nicaragua   |
# |  281685 |        Pharmacy       |    Health   |     700     | Sierra Leone |
# |  281858 |     General Store     |    Retail   |     2700    | Philippines  |
# +---------+-----------------------+-------------+-------------+--------------+
# +-------------+
# | day_of_year |
# +-------------+
# |     102     |
# |     110     |
# |     110     |
# |     110     |
# |     110     |
# |     110     |
# |     110     |
# |     103     |
# |     112     |
# |     110     |
# |     ...     |
# +-------------+
# [401765 rows x 6 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ## Train the model

# %%
# convert features into SFrame
loan_feature = gl.SFrame({'loan_id': list(raw_features['loan_id']), 
                          'activity': list(raw_features['activity']), 
                          'sector': list(raw_features['sector']), 
                          'loan_amount': list(raw_features['loan_amount']), 
                          'country': list(raw_features['country']), 
                          'day_of_year': list(raw_features['day_of_year'])})

# %%
loan_feature
# Out:
# Columns:
# 	activity	str
# 	country	str
# 	day_of_year	int
# 	loan_amount	int
# 	loan_id	str
# 	sector	str
#
# Rows: 401765
#
# Data:
# +-----------------------+--------------+-------------+-------------+---------+
# |        activity       |   country    | day_of_year | loan_amount | loan_id |
# +-----------------------+--------------+-------------+-------------+---------+
# |        Services       |     Peru     |     102     |     725     |  280242 |
# |     General Store     | Philippines  |     110     |     350     |  280741 |
# |       Livestock       | Philippines  |     110     |     600     |  280758 |
# |     General Store     | Philippines  |     110     |     575     |  280766 |
# |        Poultry        | Philippines  |     110     |     400     |  280776 |
# |      Fish Selling     | Philippines  |     110     |     475     |  280781 |
# | Food Production/Sales | Philippines  |     110     |     350     |  280785 |
# |      Fish Selling     |  Nicaragua   |     103     |     700     |  280872 |
# |        Pharmacy       | Sierra Leone |     112     |     700     |  281685 |
# |     General Store     | Philippines  |     110     |     2700    |  281858 |
# +-----------------------+--------------+-------------+-------------+---------+
# +-------------+
# |    sector   |
# +-------------+
# |   Services  |
# |    Retail   |
# | Agriculture |
# |    Retail   |
# | Agriculture |
# |     Food    |
# |     Food    |
# |     Food    |
# |    Health   |
# |    Retail   |
# |     ...     |
# +-------------+
# [401765 rows x 6 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
# split train test
train, test = gl.recommender.util.random_split_by_user(sf, user_id='lender_id', item_id='loan_id', item_test_proportion=0.2)

# %%
# Train the model
models = []
regs = [0.1, 0.01, 0.001]
num_factors = range(2, 5)
for n in num_factors:
    for r in regs:
        m = gl.recommender.ranking_factorization_recommender.create(train,
                                                                    user_id='lender_id', 
                                                                    item_id='loan_id',
                                                                    item_data=loan_feature,
                                                                    num_factors=n,
                                                                    regularization=r, 
                                                                    binary_target=True, 
                                                                    verbose=True)
        models.append(m)
# Out:
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1215403 observations with 86345 users and 803274 items.
# PROGRESS:     Data prepared in: 1.69103s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 2        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.1      |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151925 / 1215403 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.000606223       | 1.38137                                  |
# PROGRESS: | 1       | 0.000303111       | 1.38377                                  |
# PROGRESS: | 2       | 0.000151556       | 1.38501                                  |
# PROGRESS: | 3       | 7.57778e-05       | 1.38568                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.000606223       | 1.38137                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 403us        | 1.38818           | 0.693145                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.25s        | 1.38153           | 0.692664                          | 0.000606223 |
# PROGRESS: | 2       | 2.36s        | 1.37925           | 0.692283                          | 0.000606223 |
# PROGRESS: | 3       | 3.46s        | 1.3776            | 0.692026                          | 0.000606223 |
# PROGRESS: | 4       | 4.61s        | 1.37623           | 0.691811                          | 0.000606223 |
# PROGRESS: | 5       | 5.79s        | 1.37501           | 0.691616                          | 0.000606223 |
# PROGRESS: | 6       | 6.92s        | 1.37401           | 0.691425                          | 0.000606223 |
# PROGRESS: | 7       | 8.06s        | 1.37315           | 0.691245                          | 0.000606223 |
# PROGRESS: | 8       | 9.29s        | 1.3724            | 0.691067                          | 0.000606223 |
# PROGRESS: | 9       | 10.45s       | 1.37169           | 0.690894                          | 0.000606223 |
# PROGRESS: | 10      | 11.68s       | 1.37103           | 0.690728                          | 0.000606223 |
# PROGRESS: | 11      | 12.82s       | 1.3704            | 0.690564                          | 0.000606223 |
# PROGRESS: | 12      | 14.03s       | 1.36981           | 0.690404                          | 0.000606223 |
# PROGRESS: | 13      | 15.12s       | 1.36923           | 0.690248                          | 0.000606223 |
# PROGRESS: | 14      | 16.23s       | 1.36884           | 0.690094                          | 0.000606223 |
# PROGRESS: | 15      | 17.33s       | 1.36828           | 0.689941                          | 0.000606223 |
# PROGRESS: | 16      | 18.42s       | 1.36795           | 0.689795                          | 0.000606223 |
# PROGRESS: | 17      | 19.53s       | 1.36733           | 0.689644                          | 0.000606223 |
# PROGRESS: | 18      | 20.63s       | 1.36693           | 0.6895                            | 0.000606223 |

# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.33624
# PROGRESS:        Final training Predictive Error: 0.65898
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1215403 observations with 86345 users and 803274 items.
# PROGRESS:     Data prepared in: 2.15619s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 2        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.001    |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151925 / 1215403 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.0606223         | 1.30009                                  |
# PROGRESS: | 1       | 0.0303111         | 1.32032                                  |
# PROGRESS: | 2       | 0.0151556         | 1.33464                                  |
# PROGRESS: | 3       | 0.00757778        | 1.34973                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.0606223         | 1.30009                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 364us        | 1.38658           | 0.693148                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.28s        | 1.37311           | 0.644475                          | 0.0606223   |
# PROGRESS: | 2       | 2.72s        | 1.34218           | 0.660788                          | 0.0606223   |
# PROGRESS: | 3       | 3.87s        | 1.33591           | 0.657102                          | 0.0606223   |
# PROGRESS: | 4       | 5.00s        | 1.33153           | 0.655212                          | 0.0606223   |
# PROGRESS: | 5       | 6.12s        | 1.32913           | 0.654411                          | 0.0606223   |
# PROGRESS: | 6       | 7.46s        | 1.32749           | 0.65387                           | 0.0606223   |
# PROGRESS: | 7       | 8.66s        | 1.32584           | 0.653355                          | 0.0606223   |
# PROGRESS: | 8       | 9.79s        | 1.32506           | 0.652756                          | 0.0606223   |
# PROGRESS: | 9       | 11.01s       | 1.32406           | 0.652411                          | 0.0606223   |
# PROGRESS: | 10      | 12.11s       | 1.32257           | 0.652309                          | 0.0606223   |
# PROGRESS: | 11      | 13.36s       | 1.32216           | 0.651728                          | 0.0606223   |
# PROGRESS: | 12      | 14.64s       | 1.32114           | 0.651581                          | 0.0606223   |
# PROGRESS: | 13      | 16.03s       | 1.32083           | 0.651278                          | 0.0606223   |
# PROGRESS: | 14      | 17.27s       | 1.3203            | 0.65117                           | 0.0606223   |
# PROGRESS: | 15      | 18.61s       | 1.31961           | 0.650827                          | 0.0606223   |
# PROGRESS: | 16      | 19.89s       | 1.31946           | 0.650929                          | 0.0606223   |
# PROGRESS: | 17      | 21.12s       | 1.31871           | 0.650726                          | 0.0606223   |
# PROGRESS: | 18      | 22.45s       | 1.31826           | 0.65019                           | 0.0606223   |
# PROGRESS: | 19      | 23.86s       | 1.31835           | 0.650461                          | 0.0606223   |
# PROGRESS: | 20      | 25.48s       | 1.31819           | 0.650266                          | 0.0606223   |
# PROGRESS: | 21      | 26.91s       | 1.31758           | 0.650006                          | 0.0606223   |
# PROGRESS: | 22      | 28.22s       | 1.3172            | 0.650005                          | 0.0606223   |
# PROGRESS: | 23      | 29.52s       | 1.31705           | 0.649919                          | 0.0606223   |
# PROGRESS: | 24      | 31.24s       | 1.3169            | 0.649772                          | 0.0606223   |
# PROGRESS: | 25      | 33.04s       | 1.31634           | 0.649611                          | 0.0606223   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.31509
# PROGRESS:        Final training Predictive Error: 0.647922
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1215403 observations with 86345 users and 803274 items.
# PROGRESS:     Data prepared in: 2.00773s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 3        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.1      |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151925 / 1215403 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.000606223       | 1.3815                                   |
# PROGRESS: | 1       | 0.000303111       | 1.38379                                  |
# PROGRESS: | 2       | 0.000151556       | 1.38504                                  |
# PROGRESS: | 3       | 7.57778e-05       | 1.38569                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.000606223       | 1.3815                                   |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 329us        | 1.38801           | 0.69315                           |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.56s        | 1.38075           | 0.692562                          | 0.000606223 |
# PROGRESS: | 2       | 3.22s        | 1.37903           | 0.692176                          | 0.000606223 |
# PROGRESS: | 3       | 4.75s        | 1.37741           | 0.691923                          | 0.000606223 |
# PROGRESS: | 4       | 6.30s        | 1.37605           | 0.691698                          | 0.000606223 |
# PROGRESS: | 5       | 8.05s        | 1.37489           | 0.691493                          | 0.000606223 |
# PROGRESS: | 6       | 9.30s        | 1.37391           | 0.691301                          | 0.000606223 |
# PROGRESS: | 7       | 10.59s       | 1.37305           | 0.691122                          | 0.000606223 |
# PROGRESS: | 8       | 11.88s       | 1.37229           | 0.690944                          | 0.000606223 |
# PROGRESS: | 9       | 13.44s       | 1.37163           | 0.690772                          | 0.000606223 |
# PROGRESS: | 10      | 14.89s       | 1.37093           | 0.690596                          | 0.000606223 |
# PROGRESS: | 11      | 16.50s       | 1.37034           | 0.69043                           | 0.000606223 |
# PROGRESS: | 12      | 18.22s       | 1.36977           | 0.690268                          | 0.000606223 |
# PROGRESS: | 13      | 19.66s       | 1.36914           | 0.690109                          | 0.000606223 |
# PROGRESS: | 14      | 21.09s       | 1.36876           | 0.689956                          | 0.000606223 |
# PROGRESS: | 15      | 22.65s       | 1.36821           | 0.689802                          | 0.000606223 |
# PROGRESS: | 16      | 23.88s       | 1.3679            | 0.689654                          | 0.000606223 |
# PROGRESS: | 17      | 25.21s       | 1.36729           | 0.689507                          | 0.000606223 |
# PROGRESS: | 18      | 26.44s       | 1.36683           | 0.689363                          | 0.000606223 |
# PROGRESS: | 19      | 27.83s       | 1.36657           | 0.689222                          | 0.000606223 |
# PROGRESS: | 20      | 29.06s       | 1.36616           | 0.689083                          | 0.000606223 |
# PROGRESS: | 21      | 30.37s       | 1.36585           | 0.688947                          | 0.000606223 |
# PROGRESS: | 22      | 31.73s       | 1.36545           | 0.688811                          | 0.000606223 |
# PROGRESS: | 23      | 33.48s       | 1.36511           | 0.688677                          | 0.000606223 |
# PROGRESS: | 24      | 35.00s       | 1.36476           | 0.688544                          | 0.000606223 |
# PROGRESS: | 25      | 36.75s       | 1.36441           | 0.688413                          | 0.000606223 |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.36437
# PROGRESS:        Final training Predictive Error: 0.688334
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has
points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.0606223         | 1.30938                                  |
# PROGRESS: | 1       | 0.0303111         | 1.32521                                  |
# PROGRESS: | 2       | 0.0151556         | 1.33711                                  |
# PROGRESS: | 3       | 0.00757778        | 1.35077                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.0606223         | 1.30938                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 401us        | 1.38655           | 0.693149                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.27s        | 1.37916           | 0.646528                          | 0.0606223   |
# PROGRESS: | 2       | 2.46s        | 1.34378           | 0.660153                          | 0.0606223   |
# PROGRESS: | 3       | 3.73s        | 1.33672           | 0.657533                          | 0.0606223   |
# PROGRESS: | 4       | 5.05s        | 1.33208           | 0.655117                          | 0.0606223   |
# PROGRESS: | 5       | 6.30s        | 1.32928           | 0.654397                          | 0.0606223   |
# PROGRESS: | 6       | 7.65s        | 1.32792           | 0.653929                          | 0.0606223   |
# PROGRESS: | 7       | 8.94s        | 1.32577           | 0.653321                          | 0.0606223   |
# PROGRESS: | 8       | 10.28s       | 1.32434           | 0.652548                          | 0.0606223   |
# PROGRESS: | 9       | 11.55s       | 1.32409           | 0.652458                          | 0.0606223   |
# PROGRESS: | 10      | 12.79s       | 1.32265           | 0.652296                          | 0.0606223   |
# PROGRESS: | 11      | 14.05s       | 1.32197           | 0.651959                          | 0.0606223   |
# PROGRESS: | 12      | 15.23s       | 1.32121           | 0.651513                          | 0.0606223   |
# PROGRESS: | 13      | 16.42s       | 1.32095           | 0.651311                          | 0.0606223   |
# PROGRESS: | 14      | 17.69s       | 1.32023           | 0.651121                          | 0.0606223   |
# PROGRESS: | 15      | 19.08s       | 1.31958           | 0.650813                          | 0.0606223   |
# PROGRESS: | 16      | 20.44s       | 1.31962           | 0.650918                          | 0.0606223   |
# PROGRESS: | 17      | 22.25s       | 1.31858           | 0.650469                          | 0.0606223   |
# PROGRESS: | 18      | 24.15s       | 1.31831           | 0.650026                          | 0.0606223   |
# PROGRESS: | 19      | 25.48s       | 1.31817           | 0.650012                          | 0.0606223   |
# PROGRESS: | 20      | 27.25s       | 1.31854           | 0.649911                          | 0.0606223   |
# PROGRESS: | 21      | 28.63s       | 1.31766           | 0.649846                          | 0.0606223   |
# PROGRESS: | 22      | 30.43s       | 1.31722           | 0.64979                           | 0.0606223   |
# PROGRESS: | 23      | 31.73s       | 1.31723           | 0.64969                           | 0.0606223   |
# PROGRESS: | 24      | 32.93s       | 1.31692           | 0.649474                          | 0.0606223   |
# PROGRESS: | 25      | 34.30s       | 1.31644           | 0.649346                          | 0.0606223   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.31494
# PROGRESS:        Final training Predictive Error: 0.647676
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1215403 observations with 86345 users and 803274 items.
# PROGRESS:     Data prepared in: 2.22273s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 4        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.1      |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151925 / 1215403 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.000606223       | 1.38158                                  |
# PROGRESS: | 1       | 0.000303111       | 1.38385                                  |
# PROGRESS: | 2       | 0.000151556       | 1.38504                                  |
# PROGRESS: | 3       | 7.57778e-05       | 1.3857                                   |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.000606223       | 1.38158                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 347us        | 1.38854           | 0.693152                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       |
          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.29s        | 1.3573            | 0.673105                          | 0.00606223  |
# PROGRESS: | 2       | 2.37s        | 1.35071           | 0.670492                          | 0.00606223  |
# PROGRESS: | 3       | 3.47s        | 1.34745           | 0.668798                          | 0.00606223  |
# PROGRESS: | 4       | 4.78s        | 1.34525           | 0.667397                          | 0.00606223  |
# PROGRESS: | 5       | 6.14s        | 1.34364           | 0.666185                          | 0.00606223  |
# PROGRESS: | 6       | 7.43s        | 1.34257           | 0.665193                          | 0.00606223  |
# PROGRESS: | 7       | 8.94s        | 1.34182           | 0.664361                          | 0.00606223  |
# PROGRESS: | 8       | 10.07s       | 1.34116           | 0.663585                          | 0.00606223  |
# PROGRESS: | 9       | 11.27s       | 1.34066           | 0.663029                          | 0.00606223  |
# PROGRESS: | 10      | 12.51s       | 1.34022           | 0.662562                          | 0.00606223  |
# PROGRESS: | 11      | 13.63s       | 1.33988           | 0.662131                          | 0.00606223  |
# PROGRESS: | 12      | 14.94s       | 1.33935           | 0.661743                          | 0.00606223  |
# PROGRESS: | 13      | 16.46s       | 1.33889           | 0.661373                          | 0.00606223  |
# PROGRESS: | 14      | 17.85s       | 1.33874           | 0.661041                          | 0.00606223  |
# PROGRESS: | 15      | 18.94s       | 1.33837           | 0.66076                           | 0.00606223  |
# PROGRESS: | 16      | 20.22s       | 1.33848           | 0.660527                          | 0.00606223  |
# PROGRESS: | 17      | 21.65s       | 1.33782           | 0.660295                          | 0.00606223  |
# PROGRESS: | 18      | 23.11s       | 1.33756           | 0.660086                          | 0.00606223  |
# PROGRESS: | 19      | 24.63s       | 1.33764           | 0.659916                          | 0.00606223  |
# PROGRESS: | 20      | 25.98s       | 1.33722           | 0.659754                          | 0.00606223  |
# PROGRESS: | 21      | 27.39s       | 1.33724           | 0.659597                          | 0.00606223  |
# PROGRESS: | 22      | 28.61s       | 1.33685           | 0.659446                          | 0.00606223  |
# PROGRESS: | 23      | 29.71s       | 1.33674           | 0.659307                          | 0.00606223  |
# PROGRESS: | 24      | 30.81s       | 1.33653           | 0.659173                          | 0.00606223  |
# PROGRESS: | 25      | 31.99s       | 1.33635           | 0.659051                          | 0.00606223  |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.33625
# PROGRESS:        Final training Predictive Error: 0.65884
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 1215403 observations with 86345 users and 803274 items.
# PROGRESS:     Data prepared in: 1.9909s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 4        |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.001    |
# PROGRESS: | solver                         | Solver used for training                         | adagrad  |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | side_data_factorization        | Assign Factors for Side Data                     | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 151925 / 1215403 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.0606223         | 1.31766                                  |
# PROGRESS: | 1       | 0.0303111         | 1.32954                                  |
# PROGRESS: | 2       | 0.0151556         | 1.3387                                   |
# PROGRESS: | 3       | 0.00757778        | 1.35244                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.0606223         | 1.31766                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 379us        | 1.38655           | 0.693149                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.11s        | 1.40526           | 0.64792                           | 0.0606223   |
# PROGRESS: | 2       | 2.33s        | 1.34473           | 0.660547                          | 0.0606223   |
# PROGRESS: | 3       | 3.40s        | 1.33745           | 0.657344                          | 0.0606223   |
# PROGRESS: | 4       | 4.65s        | 1.33281           | 0.655254                          | 0.0606223   |
# PROGRESS: | 5       | 5.79s        | 1.32979           | 0.654422                          | 0.0606223   |
# PROGRESS: | 6       | 6.95s        | 1.32762           | 0.654091                          | 0.0606223   |
# PROGRESS: | 7       | 8.14s        | 1.32654           | 0.653318                          | 0.0606223   |
# PROGRESS: | 8       | 9.21s        | 1.32424           | 0.65269                           | 0.0606223   |
# PROGRESS: | 9       | 10.39s       | 1.32362           | 0.652737                          | 0.0606223   |
# PROGRESS: | 10      | 11.48s       | 1.32283           | 0.652213                          | 0.0606223   |
# PROGRESS: | 11      | 12.62s       | 1.32209           | 0.651821                          | 0.0606223   |
# PROGRESS: | 12      | 13.72s       | 1.32121           | 0.651532                          | 0.0606223   |
# PROGRESS: | 13      | 14.85s       | 1.32058           | 0.651432                          | 0.0606223   |
# PROGRESS: | 14      | 15.92s       | 1.3202            | 0.651221                          | 0.0606223   |
# PROGRESS: | 15      | 16.97s       | 1.31969           | 0.651138                          | 0.0606223   |
# PROGRESS: | 16      | 18.03s       | 1.31949           | 0.650875                          | 0.0606223   |
# PROGRESS: | 17      | 19.09s       | 1.31866           | 0.650757                          | 0.0606223   |
# PROGRESS: | 18      | 20.16s       | 1.31892           | 0.650383                          | 0.0606223   |
# PROGRESS: | 19      | 21.23s       | 1.31871           | 0.650284                          | 0.0606223   |
# PROGRESS: | 20      | 22.35s       | 1.31834           | 0.650285                          | 0.0606223   |
# PROGRESS: | 21      | 23.38s       | 1.31761           | 0.649961                          | 0.0606223   |
# PROGRESS: | 22      | 24.44s       | 1.31713           | 0.650115                          | 0.0606223   |
# PROGRESS: | 23      | 25.55s       | 1.31698           | 0.649832                          | 0.0606223   |
# PROGRESS: | 24      | 26.64s       | 1.3168            | 0.649709                          | 0.0606223   |
# PROGRESS: | 25      | 27.69s       | 1.31651           | 0.649574                          | 0.0606223   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.31481
# PROGRESS:        Final training Predictive Error: 0.647973
# PROGRESS: WARNING: Differing categorical key types present in list or dictionary on column loan_id; promoting all to string type.

# %%
# compare models
for i, m in enumerate(models):
    print '='*100
    print 'MODEL ', i
    m.evaluate(test, metric='precision_recall')
# Out:
# ====================================================================================================
# MODEL  0
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    | 0.000772200772201 | 0.000455812955813 |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  1
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    | 0.000772200772201 | 0.000455812955813 |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  2
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    |  0.0003861003861  |  0.0002145002145  |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  3
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    |  0.0003861003861  |  0.0002145002145  |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  4
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    | 0.000772200772201 | 0.000455812955813 |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  5
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    | 0.000772200772201 | 0.000455812955813 |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  6
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    |  0.0003861003861  |  0.0002145002145  |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  7
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    |  0.0003861003861  |  0.0002145002145  |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]
#
# ====================================================================================================
# MODEL  8
#
# Precision and recall summary statistics by cutoff
# +--------+-------------------+-------------------+
# | cutoff |   mean_precision  |    mean_recall    |
# +--------+-------------------+-------------------+
# |   5    |  0.0003861003861  |  0.0002145002145  |
# |   10   | 0.000579150579151 | 0.000536250536251 |
# |   15   |  0.0003861003861  | 0.000536250536251 |
# +--------+-------------------+-------------------+
# [3 rows x 3 columns]

# %%
test
# Out:
# Columns:
# 	lender_id	str
# 	loan_id	int
#
# Rows: 2287
#
# Data:
# +---------------+---------+
# |   lender_id   | loan_id |
# +---------------+---------+
# | 12thgrade7044 |  594009 |
# |  1plusnet1470 |  489238 |
# |  1plusnet1470 |  411121 |
# |      9678     |  636593 |
# |      9678     |  635849 |
# |      9678     |  560521 |
# |      9678     |  459634 |
# |      9678     |  433636 |
# |      9678     |  410988 |
# |      9678     |  325840 |
# |      ...      |   ...   |
# +---------------+---------+
# [2287 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.
