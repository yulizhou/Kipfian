# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
import graphlab as gl
import csv
gl.canvas.set_target('ipynb')

# %%
client = MongoClient()
kiva = client.kiva

# %% [markdown]
# ##Load data and features

# %%
# load loans_lenders data
loans_lenders = kiva.loans_lenders
cursor_loans_lenders = loans_lenders.find({'rnd': {'$lt': 0.309}}, {'_id':0, 'rnd':0}).limit(100000)
sample_loans_lenders = pd.DataFrame(list(cursor_loans_lenders))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2032ee67faed> in <module>()
#       2 loans_lenders = kiva.loans_lenders
#       3 cursor_loans_lenders = loans_lenders.find({'rnd': {'$lt': 0.309}}, {'_id':0, 'rnd':0}).limit(100000)
# ----> 4 sample_loans_lenders = pd.DataFrame(list(cursor_loans_lenders))
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymongo/cursor.pyc in next(self)
#    1074             raise StopIteration
#    1075         db = self.__collection.database
# -> 1076         if len(self.__data) or self._refresh():
#    1077             if self.__manipulate:
#    1078                 return db._fix_outgoing(self.__data.popleft(),
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymongo/cursor.pyc in _refresh(self)
#    1035                 self.__send_message(
#    1036                     message.get_more(self.__collection.full_name,
# -> 1037                                      limit, self.__id))
#    1038
#    1039         else:  # Cursor id is zero nothing else to return
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymongo/cursor.pyc in __send_message(self, message)
#     931
#     932             try:
# --> 933                 res = client._send_message_with_response(message, **kwargs)
#     934                 self.__connection_id, (response, sock, pool) = res
#     935                 if self.__exhaust:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _send_message_with_response(self, message, _must_use_master, **kwargs)
#    1203                 sock_info.sock.settimeout(kwargs["network_timeout"])
#    1204
# -> 1205             response = self.__send_and_receive(message, sock_info)
#    1206
#    1207             if not exhaust:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymongo/mongo_client.pyc in __send_and_receive(self, message, sock_info)
#    1180         try:
#    1181             sock_info.sock.sendall(data)
# -> 1182             return self.__receive_message_on_socket(1, request_id, sock_info)
#    1183         except:
#    1184             sock_info.close()
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymongo/mongo_client.pyc in __receive_message_on_socket(self, operation, rqst_id, sock_info)
#    1163         Returns the response data with the header removed.
#    1164         """
# -> 1165         header = self.__receive_data_on_socket(16, sock_info)
#    1166         length = struct.unpack("<i", header[:4])[0]
#    1167         # No rqst_id for exhaust cursor "getMore".
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pymongo/mongo_client.pyc in __receive_data_on_socket(self, length, sock_info)
#    1151         message = EMPTY
#    1152         while length:
# -> 1153             chunk = sock_info.sock.recv(length)
#    1154             if chunk == EMPTY:
#    1155                 raise ConnectionFailure("connection closed")
#
# KeyboardInterrupt:

# %%
sample_loans_lenders = sample_loans_lenders.dropna()

# %%
sample_loans_lenders.info()

# %%
with open('data/loan_lender_100000.csv', 'w') as f:
    wr = csv.writer(f, delimiter=',')
    for r in sample_loans_lenders.iterrows():
        for l in r[1]['lender_ids']:
            wr.writerow([r[1]['id'], l, 1])

# %%
sf = gl.SFrame.read_csv('data/loan_lender_100000.csv', header=False, delimiter=',', verbose=True)
sf.rename({'X1':'loan_id', 'X2':'lender_id', 'X3':'lended'}).show()
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-2363 - Server binary: /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1425504474.log
# [INFO] GraphLab Server Version: 1.3.0
# PROGRESS: Finished parsing file /Users/yulizhou/Documents/Projects/zipfian/Kipfian/data/loan_lender_100000.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 1.50567 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /Users/yulizhou/Documents/Projects/zipfian/Kipfian/data/loan_lender_100000.csv
# PROGRESS: Parsing completed. Parsed 2295765 lines in 1.66516 secs.

# %%
# split train test
train, test = gl.recommender.util.random_split_by_user(sf, user_id='lender_id', item_id='loan_id', item_test_proportion=0.2)

# %% [markdown]
# ###Model selection
# "If your data is implicit, i.e., you only observe interactions between users and items, without a rating, then use item_similarity_recommender with Jaccard similarity (default) or the ranking_factorization_recommender." [link](https://dato.com/learn/userguide/index.html#Modeling_data_Recommender_systems)

# %%
models = []
# train the model
m_iter0 = gl.recommender.item_similarity_recommender.create(train, user_id='lender_id', item_id='loan_id', target='lended')
models.append(m_iter0)
# Out:
# PROGRESS: Recsys training: model = item_similarity
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 2294839 observations with 461730 users and 99491 items.
# PROGRESS:     Data prepared in: 2.35078s
# PROGRESS: Processing 2294839 observations:
# PROGRESS:    Observations   Seconds
# PROGRESS:         1000000   40.3618
# PROGRESS:         2000000    83.933
# PROGRESS:         2294839   96.0254
# PROGRESS: Computing similar items for 99491 items using 8 partitions:
# PROGRESS:  Partition     Items   Seconds
# PROGRESS:          0     12446   97.2406
# PROGRESS:          1     24883   98.6759
# PROGRESS:          2     37320   100.197
# PROGRESS:          3     49756    101.85
# PROGRESS:          4     62185   103.294
# PROGRESS:          5     74616   104.686
# PROGRESS:          6     87052   106.122
# PROGRESS:          7     99491   107.643
# PROGRESS: Finished getting similar items for 99491 items in 107.644s.
# PROGRESS: Finished training in 112.554s
# PROGRESS: Finished prediction in 4.86731s

# %%
# Try factorization
regs = [0.1, 0.01, 0.001, 0.0001]
for r in regs:
    m = gl.recommender.ranking_factorization_recommender.create(train,
                                                                user_id='lender_id', 
                                                                item_id='loan_id', 
                                                                target='lended',
                                                                regularization=r, 
                                                                binary_target=True)
    models.append(m)
# Out:
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 2294839 observations with 461730 users and 99491 items.
# PROGRESS:     Data prepared in: 2.26169s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 32       |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.1      |
# PROGRESS: | solver                         | Solver used for training                         | sgd      |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | ranking_regularization         | Rank-based Regularization Weight                 | 0.25     |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 286854 / 2294839 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.000321075       | 1.38628                                  |
# PROGRESS: | 1       | 0.000160537       | 1.38717                                  |
# PROGRESS: | 2       | 8.02687e-05       | 1.39964                                  |
# PROGRESS: | 3       | 4.01344e-05       | 1.4364                                   |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.000321075       | 1.38628                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 367us        | 1.62726           | 0.313261                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.12s        | DIVERGED          | DIVERGED                          | 0.000321075 |
# PROGRESS: | RESET   | 2.17s        | 1.62726           | 0.31326                           |             |
# PROGRESS: | 1       | 3.81s        | DIVERGED          | DIVERGED                          | 0.000160537 |
# PROGRESS: | RESET   | 4.87s        | 1.62725           | 0.313261                          |             |
# PROGRESS: | 1       | 6.50s        | DIVERGED          | DIVERGED                          | 8.02687e-05 |
# PROGRESS: | RESET   | 7.56s        | 1.62726           | 0.313262                          |             |
# PROGRESS: | 1       | 8.65s        | 1.41009           | 0.609433                          | 4.01344e-05 |
# PROGRESS: | 2       | 9.70s        | 1.38633           | 0.691681                          | 3.93081e-06 |
# PROGRESS: | 3       | 10.78s       | 1.38632           | 0.691861                          | 2.06661e-06 |
# PROGRESS: | 4       | 11.84s       | 1.38631           | 0.692086                          | 1.4018e-06  |
# PROGRESS: | 5       | 12.91s       | 1.38631           | 0.69205                           | 1.06061e-06 |
# PROGRESS: | 6       | 14.00s       | 1.3863            | 0.692139                          | 8.52998e-07 |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Convergence on objective within bounds.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.3863
# PROGRESS:        Final training Predictive Error: 0.692094
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 2294839 observations with 461730 users and 99491 items.
# PROGRESS:     Data prepared in: 2.30884s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 32       |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.01     |
# PROGRESS: | solver                         | Solver used for training                         | sgd      |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | ranking_regularization         | Rank-based Regularization Weight                 | 0.25     |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 286854 / 2294839 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.00321075        | Not Viable                               |
# PROGRESS: | 1       | 0.000802687       | 1.3862                                   |
# PROGRESS: | 2       | 0.000401344       | 1.38624                                  |
# PROGRESS: | 3       | 0.000200672       | 1.3863                                   |
# PROGRESS: | 4       | 0.000100336       | 1.3871                                   |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.000802687       | 1.3862                                   |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 331us        | 1.6268            | 0.31326                           |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.62s        | DIVERGED          | DIVERGED                          | 0.000802687 |
# PROGRESS: | RESET   | 2.70s        | 1.62679           | 0.313262                          |             |
# PROGRESS: | 1       | 4.31s        | DIVERGED          | DIVERGED                          | 0.000401344 |
# PROGRESS: | RESET   | 5.38s        | 1.62679           | 0.313262                          |             |
# PROGRESS: | 1       | 6.46s        | 1.39099           | 0.675078                          | 0.000200672 |
# PROGRESS: | 2       | 7.50s        | 1.38613           | 0.69226                           | 3.58017e-05 |
# PROGRESS: | 3       | 8.55s        | 1.38605           | 0.691808                          | 1.96541e-05 |
# PROGRESS: | 4       | 9.59s        | 1.38602           | 0.692353                          | 1.35449e-05 |
# PROGRESS: | 5       | 10.64s       | 1.386             | 0.691829                          | 1.03331e-05 |
# PROGRESS: | 6       | 11.68s       | 1.38598           | 0.692169                          | 8.35246e-06 |
# PROGRESS: | 7       | 12.72s       | 1.38597           | 0.691997                          | 7.00901e-06 |
# PROGRESS: | 8       | 13.79s       | 1.38596           | 0.691742                          | 6.03785e-06 |
# PROGRESS: | 9       | 14.84s       | 1.38595           | 0.691731                          | 5.30306e-06 |
# PROGRESS: | 10      | 15.88s       | 1.38594           | 0.691986                          | 4.72771e-06 |
# PROGRESS: | 11      | 17.00s       | 1.38594           | 0.691942                          | 4.26499e-06 |
# PROGRESS: | 12      | 18.06s       | 1.38593           | 0.692                             | 3.88477e-06 |
# PROGRESS: | 13      | 19.15s       | 1.38593           | 0.691973                          | 3.56679e-06 |
# PROGRESS: | 14      | 20.20s       | 1.38592           | 0.691969                          | 3.29693e-06 |
# PROGRESS: | 15      | 21.26s       | 1.38592           | 0.691938                          | 3.06503e-06 |
# PROGRESS: | 16      | 22.30s       | 1.38591           | 0.691844                          | 2.86361e-06 |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Convergence on objective within bounds.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.38591
# PROGRESS:        Final training Predictive Error: 0.691799
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 2294839 observations with 461730 users and 99491 items.
# PROGRESS:     Data prepared in: 2.27181s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 32       |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.001    |
# PROGRESS: | solver                         | Solver used for training                         | sgd      |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | ranking_regularization         | Rank-based Regularization Weight                 | 0.25     |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 286854 / 2294839 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.0321075         | Not Viable                               |
# PROGRESS: | 1       | 0.00802687        | 1.38538                                  |
# PROGRESS: | 2       | 0.00401344        | 1.38563                                  |
# PROGRESS: | 3       | 0.00200672        | 1.38583                                  |
# PROGRESS: | 4       | 0.00100336        | 1.38599                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.00802687        | 1.38538                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 351us        | 1.62675           | 0.313261                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.65s        | DIVERGED          | DIVERGED                          | 0.00802687  |
# PROGRESS: | RESET   | 2.72s        | 1.62675           | 0.313262                          |             |
# PROGRESS: | 1       | 4.37s        | DIVERGED          | DIVERGED                          | 0.00401344  |
# PROGRESS: | RESET   | 5.41s        | 1.62675           | 0.313261                          |             |
# PROGRESS: | 1       | 6.50s        | 1.38628           | 0.690422                          | 0.00200672  |
# PROGRESS: | 2       | 7.56s        | 1.3845            | 0.691675                          | 0.000358017 |
# PROGRESS: | 3       | 8.63s        | 1.38402           | 0.691197                          | 0.000196541 |
# PROGRESS: | 4       | 9.70s        | 1.38383           | 0.691184                          | 0.000135449 |
# PROGRESS: | 5       | 10.77s       | 1.38371           | 0.691145                          | 0.000103331 |
# PROGRESS: | 6       | 11.85s       | 1.38362           | 0.690957                          | 8.35246e-05 |
# PROGRESS: | 7       | 12.90s       | 1.38356           | 0.691223                          | 7.00901e-05 |
# PROGRESS: | 8       | 13.96s       | 1.38349           | 0.69087                           | 6.03785e-05 |
# PROGRESS: | 9       | 15.03s       | 1.38345           | 0.690876                          | 5.30306e-05 |
# PROGRESS: | 10      | 16.10s       | 1.38342           | 0.690971                          | 4.72771e-05 |
# PROGRESS: | 11      | 17.16s       | 1.38339           | 0.691142                          | 4.26499e-05 |
# PROGRESS: | 12      | 18.23s       | 1.38335           | 0.691117                          | 3.88477e-05 |
# PROGRESS: | 13      | 19.27s       | 1.38332           | 0.691026                          | 3.56679e-05 |
# PROGRESS: | 14      | 20.34s       | 1.38333           | 0.691044                          | 3.29693e-05 |
# PROGRESS: | 15      | 21.41s       | 1.38327           | 0.690747                          | 3.0562e-05  |
# PROGRESS: | 16      | 22.49s       | 1.38326           | 0.690892                          | 2.84679e-05 |
# PROGRESS: | 17      | 23.60s       | 1.38323           | 0.691059                          | 2.66273e-05 |
# PROGRESS: | 18      | 24.68s       | 1.38323           | 0.690976                          | 2.50939e-05 |
# PROGRESS: | 19      | 25.78s       | 1.38321           | 0.690804                          | 2.36386e-05 |
# PROGRESS: | 20      | 26.85s       | 1.38319           | 0.690916                          | 2.23278e-05 |
# PROGRESS: | 21      | 27.92s       | 1.38319           | 0.690684                          | 2.11389e-05 |
# PROGRESS: | 22      | 28.99s       | 1.38317           | 0.690722                          | 2.01608e-05 |
# PROGRESS: | 23      | 30.05s       | 1.38316           | 0.690698                          | 1.92693e-05 |
# PROGRESS: | 24      | 31.12s       | 1.38314           | 0.690856                          | 1.84533e-05 |
# PROGRESS: | 25      | 32.18s       | 1.38313           | 0.690993                          | 1.77036e-05 |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.38314
# PROGRESS:        Final training Predictive Error: 0.691095
# PROGRESS: Recsys training: model = ranking_factorization_recommender
# PROGRESS: Preparing data set.
# PROGRESS:     Data has 2294839 observations with 461730 users and 99491 items.
# PROGRESS:     Data prepared in: 2.19631s
# PROGRESS: Training ranking_factorization_recommender for recommendations.
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | Parameter                      | Description                                      | Value    |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS: | num_factors                    | Factor Dimension                                 | 32       |
# PROGRESS: | regularization                 | L2 Regularization on Factors                     | 0.0001   |
# PROGRESS: | solver                         | Solver used for training                         | sgd      |
# PROGRESS: | linear_regularization          | L2 Regularization on Linear Coefficients         | 1e-09    |
# PROGRESS: | ranking_regularization         | Rank-based Regularization Weight                 | 0.25     |
# PROGRESS: | binary_target                  | Assume Binary Targets                            | True     |
# PROGRESS: | max_iterations                 | Maximum Number of Iterations                     | 25       |
# PROGRESS: +--------------------------------+--------------------------------------------------+----------+
# PROGRESS:   Optimizing model using SGD; tuning step size.
# PROGRESS:   Using 286854 / 2294839 points for tuning the step size.
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Attempt | Initial Step Size | Estimated Objective Value                |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | 0       | 0.321075          | Not Viable                               |
# PROGRESS: | 1       | 0.0802687         | 1.38541                                  |
# PROGRESS: | 2       | 0.0401344         | 1.38278                                  |
# PROGRESS: | 3       | 0.0200672         | 1.38287                                  |
# PROGRESS: | 4       | 0.0100336         | 1.38371                                  |
# PROGRESS: | 5       | 0.0050168         | 1.3845                                   |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: | Final   | 0.0401344         | 1.38278                                  |
# PROGRESS: +---------+-------------------+------------------------------------------+
# PROGRESS: Starting Optimization.
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Iter.   | Elapsed Time | Approx. Objective | Approx. Training Predictive Error | Step Size   |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | Initial | 375us        | 1.62675           | 0.313261                          |             |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: | 1       | 1.62s        | DIVERGED          | DIVERGED                          | 0.0401344   |
# PROGRESS: | RESET   | 2.67s        | 1.62674           | 0.31326                           |             |
# PROGRESS: | 1       | 4.32s        | DIVERGED          | DIVERGED                          | 0.0200672   |
# PROGRESS: | RESET   | 5.37s        | 1.62674           | 0.313261                          |             |
# PROGRESS: | 1       | 6.51s        | 1.38575           | 0.69166                           | 0.0100336   |
# PROGRESS: | 2       | 7.60s        | 1.3825            | 0.690509                          | 0.00303814  |
# PROGRESS: | 3       | 8.66s        | 1.38074           | 0.689625                          | 0.00179008  |
# PROGRESS: | 4       | 9.72s        | 1.3802            | 0.68939                           | 0.00126885  |
# PROGRESS: | 5       | 10.81s       | 1.37981           | 0.689324                          | 0.000982704 |
# PROGRESS: | 6       | 11.91s       | 1.37954           | 0.689361                          | 0.00080187  |
# PROGRESS: | 7       | 13.05s       | 1.37945           | 0.689494                          | 0.000677246 |
# PROGRESS: | 8       | 14.17s       | 1.37938           | 0.689395                          | 0.000586148 |
# PROGRESS: | 9       | 15.27s       | 1.3792            | 0.68903                           | 0.000516653 |
# PROGRESS: | 10      | 16.41s       | 1.37906           | 0.689314                          | 0.000461889 |
# PROGRESS: | 11      | 17.51s       | 1.3791            | 0.689134                          | 0.000417623 |
# PROGRESS: | 12      | 18.58s       | 1.379             | 0.689018                          | 0.00037838  |
# PROGRESS: | 13      | 19.71s       | 1.37904           | 0.68918                           | 0.000345452 |
# PROGRESS: | 14      | 20.83s       | 1.37899           | 0.689047                          | 0.000317369 |
# PROGRESS: | 15      | 21.91s       | 1.37895           | 0.688905                          | 0.000293074 |
# PROGRESS: | 16      | 23.03s       | 1.37885           | 0.689256                          | 0.000271791 |
# PROGRESS: | 17      | 24.11s       | 1.37888           | 0.688986                          | 0.000255834 |
# PROGRESS: | 18      | 25.18s       | 1.37887           | 0.688974                          | 0.000239056 |
# PROGRESS: | 19      | 26.30s       | 1.37886           | 0.688972                          | 0.000223917 |
# PROGRESS: | 20      | 27.38s       | 1.37891           | 0.68905                           | 0.000210135 |
# PROGRESS: | 21      | 28.49s       | 1.37874           | 0.68887                           | 0.000197481 |
# PROGRESS: | 22      | 29.58s       | 1.37872           | 0.688879                          | 0.000174608 |
# PROGRESS: | 23      | 30.63s       | 1.37874           | 0.688677                          | 0.000142013 |
# PROGRESS: | 24      | 31.70s       | 1.37872           | 0.688857                          | 0.000115667 |
# PROGRESS: | 25      | 32.75s       | 1.37876           | 0.688789                          | 9.43309e-05 |
# PROGRESS: +---------+--------------+-------------------+-----------------------------------+-------------+
# PROGRESS: Optimization Complete: Maximum number of passes through the data reached.
# PROGRESS: Computing final objective value and training Predictive Error.
# PROGRESS:        Final objective value: 1.37884
# PROGRESS:        Final training Predictive Error: 0.689215

# %%
# test
for i, m in enumerate(models):
    print '='*100
    print 'MODEL ', i
    m.evaluate(test, metric='rmse')
# Out:
# ====================================================================================================
# MODEL  0
# PROGRESS: Finished prediction in 0.32626s
#
# Overall RMSE:  37.1190924049
#
# Per User RMSE (best)
# +-----------+-------+------+
# | lender_id | count | rmse |
# +-----------+-------+------+
# |  ann5966  |   1   | 0.0  |
# +-----------+-------+------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +------------+-------+-------+
# | lender_id  | count |  rmse |
# +------------+-------+-------+
# | bonnie5150 |   1   | 449.0 |
# +------------+-------+-------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-------+------+
# | loan_id | count | rmse |
# +---------+-------+------+
# |  588721 |   1   | 0.0  |
# +---------+-------+------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------+-------+
# | loan_id | count |  rmse |
# +---------+-------+-------+
# |  429961 |   1   | 449.0 |
# +---------+-------+-------+
# [1 rows x 3 columns]
#
# ====================================================================================================
# MODEL  1
#
# Overall RMSE:  0.498841606832
#
# Per User RMSE (best)
# +-------------+-------+----------------+
# |  lender_id  | count |      rmse      |
# +-------------+-------+----------------+
# | darinka2226 |   2   | 0.497507945062 |
# +-------------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +-------------+-------+----------------+
# |  lender_id  | count |      rmse      |
# +-------------+-------+----------------+
# | michael6729 |   37  | 0.499132417441 |
# +-------------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-------+----------------+
# | loan_id | count |      rmse      |
# +---------+-------+----------------+
# |  574352 |   1   | 0.496327517203 |
# +---------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------+----------------+
# | loan_id | count |      rmse      |
# +---------+-------+----------------+
# |  682757 |   1   | 0.499197973664 |
# +---------+-------+----------------+
# [1 rows x 3 columns]
#
# ====================================================================================================
# MODEL  2
#
# Overall RMSE:  0.499096919529
#
# Per User RMSE (best)
# +-------------+-------+---------------+
# |  lender_id  | count |      rmse     |
# +-------------+-------+---------------+
# | darinka2226 |   2   | 0.48983888001 |
# +-------------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------------+-------+----------------+
# |  lender_id   | count |      rmse      |
# +--------------+-------+----------------+
# | john54726636 |   1   | 0.499674647573 |
# +--------------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-------+----------------+
# | loan_id | count |      rmse      |
# +---------+-------+----------------+
# |  574352 |   1   | 0.481351728391 |
# +---------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------+----------------+
# | loan_id | count |      rmse      |
# +---------+-------+----------------+
# |  592080 |   1   | 0.499674746747 |
# +---------+-------+----------------+
# [1 rows x 3 columns]
#
# ====================================================================================================
# MODEL  3
#
# Overall RMSE:  0.499358359137
#
# Per User RMSE (best)
# +-------------+-------+----------------+
# |  lender_id  | count |      rmse      |
# +-------------+-------+----------------+
# | darinka2226 |   2   | 0.423163422027 |
# +-------------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +-------------------+-------+----------------+
# |     lender_id     | count |      rmse      |
# +-------------------+-------+----------------+
# | carleendorian7137 |   3   | 0.503624350776 |
# +-------------------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-------+----------------+
# | loan_id | count |      rmse      |
# +---------+-------+----------------+
# |  574352 |   1   | 0.350640927399 |
# +---------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------+----------------+
# | loan_id | count |      rmse      |
# +---------+-------+----------------+
# |  793213 |   1   | 0.503630427607 |
# +---------+-------+----------------+
# [1 rows x 3 columns]
#
# ====================================================================================================
# MODEL  4
#
# Overall RMSE:  0.499439761803
#
# Per User RMSE (best)
# +-----------+-------+---------------+
# | lender_id | count |      rmse     |
# +-----------+-------+---------------+
# |  rich4015 |   1   | 0.30148439919 |
# +-----------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +---------------------+-------+----------------+
# |      lender_id      | count |      rmse      |
# +---------------------+-------+----------------+
# | grosvenorschool4557 |   1   | 0.513954743827 |
# +---------------------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +---------+-------+---------------+
# | loan_id | count |      rmse     |
# +---------+-------+---------------+
# |  574352 |   1   | 0.16534779687 |
# +---------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------+-------+----------------+
# | loan_id | count |      rmse      |
# +---------+-------+----------------+
# |  363026 |   1   | 0.517287129455 |
# +---------+-------+----------------+
# [1 rows x 3 columns]

# %%
# Take a look at recommendations for the same user
for i, m in enumerate(models):
    print '='*100
    print 'MODEL ', i
    print m.recommend(users=['andrew9629'])
# Out:
# ====================================================================================================
# MODEL  0
# +------------+---------+---------------+------+
# | lender_id  | loan_id |     score     | rank |
# +------------+---------+---------------+------+
# | andrew9629 |  557391 | 1.01470588235 |  1   |
# | andrew9629 |  713925 | 1.01041666667 |  2   |
# | andrew9629 |  440534 | 1.00729927007 |  3   |
# | andrew9629 |  566724 |      1.0      |  4   |
# | andrew9629 |  446847 |      1.0      |  5   |
# | andrew9629 |  718438 |      1.0      |  6   |
# | andrew9629 |  377780 |      1.0      |  7   |
# | andrew9629 |  531239 |      1.0      |  8   |
# | andrew9629 |  583313 |      1.0      |  9   |
# | andrew9629 |  794188 |      1.0      |  10  |
# +------------+---------+---------------+------+
# [10 rows x 4 columns]
#
# ====================================================================================================
# MODEL  1
# +------------+---------+----------------+------+
# | lender_id  | loan_id |     score      | rank |
# +------------+---------+----------------+------+
# | andrew9629 |  634057 | 0.508306141745 |  1   |
# | andrew9629 |  798219 | 0.504968842912 |  2   |
# | andrew9629 |  812994 | 0.503862603415 |  3   |
# | andrew9629 |  574371 | 0.503747214807 |  4   |
# | andrew9629 |  574352 | 0.503685679206 |  5   |
# | andrew9629 |  613821 | 0.503362980337 |  6   |
# | andrew9629 |  432419 | 0.50318209614  |  7   |
# | andrew9629 |  574362 | 0.503144727386 |  8   |
# | andrew9629 |  735279 | 0.503131400685 |  9   |
# | andrew9629 |  754811 | 0.503013790495 |  10  |
# +------------+---------+----------------+------+
# [10 rows x 4 columns]
#
# ====================================================================================================
# MODEL  2
# +------------+---------+----------------+------+
# | lender_id  | loan_id |     score      | rank |
# +------------+---------+----------------+------+
# | andrew9629 |  634057 |  0.549112507   |  1   |
# | andrew9629 |  798219 | 0.527518624743 |  2   |
# | andrew9629 |  812994 | 0.520085085071 |  3   |
# | andrew9629 |  574352 | 0.51863565655  |  4   |
# | andrew9629 |  574371 | 0.518236262449 |  5   |
# | andrew9629 |  574362 | 0.516363120346 |  6   |
# | andrew9629 |  613821 | 0.51557030979  |  7   |
# | andrew9629 |  432419 | 0.515230001714 |  8   |
# | andrew9629 |  754811 | 0.513910312142 |  9   |
# | andrew9629 |  773689 | 0.513826379848 |  10  |
# +------------+---------+----------------+------+
# [10 rows x 4 columns]
#
# ====================================================================================================
# MODEL  3
# +------------+---------+----------------+------+
# | lender_id  | loan_id |     score      | rank |
# +------------+---------+----------------+------+
# | andrew9629 |  634057 | 0.78545016847  |  1   |
# | andrew9629 |  798219 | 0.699538202129 |  2   |
# | andrew9629 |  812994 | 0.65619760023  |  3   |
# | andrew9629 |  574352 | 0.64868974662  |  4   |
# | andrew9629 |  574371 | 0.646151582579 |  5   |
# | andrew9629 |  574362 | 0.630060495283 |  6   |
# | andrew9629 |  613821 | 0.621976723906 |  7   |
# | andrew9629 |  432419 | 0.618115658601 |  8   |
# | andrew9629 |  754811 | 0.613648113085 |  9   |
# | andrew9629 |  735279 | 0.613385640395 |  10  |
# +------------+---------+----------------+------+
# [10 rows x 4 columns]
#
# ====================================================================================================
# MODEL  4
# +------------+---------+----------------+------+
# | lender_id  | loan_id |     score      | rank |
# +------------+---------+----------------+------+
# | andrew9629 |  634057 | 0.924859196063 |  1   |
# | andrew9629 |  798219 | 0.877014730311 |  2   |
# | andrew9629 |  812994 | 0.845169053904 |  3   |
# | andrew9629 |  574352 | 0.833702825559 |  4   |
# | andrew9629 |  574371 | 0.830542116543 |  5   |
# | andrew9629 |  574362 | 0.816106742243 |  6   |
# | andrew9629 |  613821 | 0.809182489193 |  7   |
# | andrew9629 |  432419 | 0.803559596574 |  8   |
# | andrew9629 |  613165 | 0.793517525889 |  9   |
# | andrew9629 |  735279 | 0.792450660894 |  10  |
# +------------+---------+----------------+------+
# [10 rows x 4 columns]
