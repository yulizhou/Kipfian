# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import graphlab as gl
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize
from sklearn.decomposition import NMF
import string
# %matplotlib inline

# %%
loans = pd.read_csv('data/loans.csv')

# %%
# pick loans which have over 400 lenders
# since the lowest amount to lend is $25, 400*25=$10000
df = loans[['sector', 'descriptions', 'use', 'lender_count', 'loan_amount']]
df = df[df['sector']!='sector']

# %%
df['lender_count'] = df['lender_count'].astype(int)
df['loan_amount'] = df['loan_amount'].astype(int)
df.dropna(inplace=True)
df = df[df['lender_count'] > 100]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18237 entries, 156 to 842804
# Data columns (total 5 columns):
# sector          18237 non-null object
# descriptions    18237 non-null object
# use             18237 non-null object
# lender_count    18237 non-null int64
# loan_amount     18237 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 854.9+ KB

# %%
def tokenize(doc):
    '''
    INPUT: string
    OUTPUT: list of strings

    Tokenize and stem/lemmatize the document.
    '''
    snowball = SnowballStemmer('english')
    punc = set(string.punctuation)
    return [snowball.stem(word) for word in word_tokenize(doc.lower()) if word not in punc]

def get_vectorizer(descriptions, num_features=2000):
    vect = TfidfVectorizer(max_features=num_features, stop_words='english', tokenizer=tokenize)
    return vect.fit(descriptions)

# %% [markdown]
# ##Description topics

# %%
# create tfidf of descriptions
desc = df.sort('lender_count', ascending=False)['descriptions'].values
vec_desc = get_vectorizer(desc)
tfidf_desc = vec_desc.transform(desc).toarray()

# %%
vec_desc.transform(desc)
# Out:
# <18237x2000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1116292 stored elements in Compressed Sparse Row format>

# %%
# run NMF and get topics
topic_words = []
nmf_desc = NMF(n_components=15).fit(tfidf_desc)
feature_names = vec_desc.get_feature_names()

# %%
num_top_words = 25
for topic in nmf_desc.components_:
    word_idx = np.argsort(topic)[::-1][0:num_top_words]
    topic_words.append([feature_names[i] for i in word_idx])

# %%
topic_words
# Out:
# [[u'busi',
#   u'hope',
#   u'shop',
#   u'profit',
#   u'open',
#   u'custom',
#   u'week',
#   u'good',
#   u'receiv',
#   u'loan',
#   u'oper',
#   u'age',
#   u'year',
#   u'expand',
#   u'develop',
#   u'say',
#   u'rdc',
#   u'kinshasa',
#   u'retail',
#   u'store',
#   u'manag',
#   u'unit',
#   u'mfi',
#   u'start',
#   u'run'],
#  [u'pro',
#   u'mujer',
#   u'sale',
#   u'sell',
#   u'member',
#   u'like',
#   u'busi',
#   u'invit',
#   u'board',
#   u'communal',
#   u'cycl',
#   u'institut',
#   u'join',
#   u'ask',
#   u'benefit',
#   u'bank',
#   u'say',
#   u'director',
#   u'blanket',
#   u'presid',
#   u'capit',
#   u'alto',
#   u'generat',
#   u'ago',
#   u'allow'],
#  [u'acr',
#   u'farmer',
#   u'fund',
#   u'harvest',
#   u'group',
#   u'seed',
#   u'repres',
#   u'leader',
#   u'fertil',
#   u'\xbc',
#   u'farm',
#   u'season',
#   u'kiva',
#   u'sorghum',
#   u'save',
#   u'cost',
#   u'millet',
#   u'maiz',
#   u'communiti',
#   u'support',
#   u'pictur',
#   u'photo',
#   u'profit',
#   u'price',
#   u'plant'],
#  [u'loan',
#   u'tanzania',
#   u'tujijeng',
#   u'hold',
#   u'account',
#   u'pay',
#   u'abl',
#   u'share',
#   u'daili',
#   u'month',
#   u'paid',
#   u'previous',
#   u'total',
#   u'use',
#   u'profit.thi',
#   u'dream',
#   u'member',
#   u"''",
#   u'success',
#   u'day',
#   u'``',
#   u'school',
#   u'make',
#   u'group',
#   u'earli'],
#  [u'year',
#   u'children',
#   u'school',
#   u'turam',
#   u'old',
#   u'group',
#   u'capit',
#   u'rice',
#   u'buy',
#   u'marri',
#   u'sell',
#   u'age',
#   u'larg',
#   u'increas',
#   u'loan',
#   u'bean',
#   u'bujumbura',
#   u'togeth',
#   u'quantiti',
#   u'live',
#   u'earn',
#   u'attend',
#   u'kiva',
#   u'banana',
#   u'come'],
#  [u'villag',
#   u'farm',
#   u'husband',
#   u'cultiv',
#   u'agricultur',
#   u'famili',
#   u'incom',
#   u'cow',
#   u'livestock',
#   u'pig',
#   u'help',
#   u'son',
#   u'cattl',
#   u'live',
#   u'fertil',
#   u'purchas',
#   u'land',
#   u'loan',
#   u"'s",
#   u'grow',
#   u'breed',
#   u'u',
#   u'crop',
#   u'mrs.',
#   u'rais'],
#  [u'p',
#   u'br',
#   u'/p',
#   u'translat',
#   u'/strong',
#   u'strong',
#   u'volunt',
#   u'spanish',
#   u'member',
#   u'kiva',
#   u'group',
#   u'sell',
#   u'product',
#   u'food',
#   u'sale',
#   u'competit',
#   u'cloth',
#   u'respons',
#   u'cosmet',
#   u'merchandis',
#   u'associ',
#   u'differ',
#   u'need',
#   u'cycl',
#   u'qualiti'],
#  [u'esperanza',
#   u'busi',
#   u'group',
#   u'coordin',
#   u'invest',
#   u'use',
#   u'loan',
#   u'excit',
#   u'dominican',
#   u'plan',
#   u'structur',
#   u'simpl',
#   u'water',
#   u'home',
#   u'cloth',
#   u'shoe',
#   u'challeng',
#   u'locat',
#   u'electr',
#   u'area',
#   u'haiti',
#   u'partner',
#   u'long-term',
#   u'product',
#   u'1'],
#  [u'banc',
#   u'group',
#   u'villageoi',
#   u'women',
#   u'right',
#   u'franc',
#   u'hand',
#   u'rais',
#   u'creat',
#   u'villag',
#   u'photo',
#   u'stand',
#   u'activ',
#   u'mother',
#   u"'s",
#   u'profit',
#   u'boy',
#   u'far',
#   u'children',
#   u'girl',
#   u'save',
#   u'solidar',
#   u'main',
#   u'retail',
#   u'marri'],
#  [u'hous',
#   u'mongolia',
#   u'live',
#   u'mnt',
#   u'son',
#   u'wife',
#   u'ulaanbaatar',
#   u'husband',
#   u'citi',
#   u'materi',
#   u'insul',
#   u'build',
#   u'famili',
#   u'year',
#   u'daughter',
#   u'pollut',
#   u'old',
#   u'coal',
#   u'air',
#   u'work',
#   u'repair',
#   u'request',
#   u'local',
#   u'heat',
#   u'car'],
#  [u'iraq',
#   u'sew',
#   u'iraqi',
#   u'client',
#   u'capac',
#   u'intern',
#   u'unabl',
#   u'microfin',
#   u'relief',
#   u'group',
#   u'repay',
#   u'individu',
#   u'machin',
#   u'loan',
#   u'borrow',
#   u'lender',
#   u'work',
#   u'evalu',
#   u'guarantor',
#   u'lowest',
#   u'provid',
#   u'offer',
#   u'skill',
#   u'guarante',
#   u'appli'],
#  [u'bank',
#   u'communal',
#   u'member',
#   u'cusco',
#   u'sell',
#   u'anim',
#   u'work',
#   u'citi',
#   u'pig',
#   u'provinc',
#   u'rais',
#   u'chicken',
#   u'guinea',
#   u'locat',
#   u'belong',
#   u'groceri',
#   u'store',
#   u'depart',
#   u'dream',
#   u'district',
#   u'busi',
#   u'grate',
#   u'payment',
#   u'photo',
#   u'differ'],
#  [u'veri',
#   u'help',
#   u'work',
#   u'women',
#   u'becaus',
#   u'continu',
#   u'group',
#   u'abl',
#   u'custom',
#   u'sell',
#   u'want',
#   u'famili',
#   u'make',
#   u'committe',
#   u'order',
#   u'life',
#   u"'s",
#   u'better',
#   u'product',
#   u'good',
#   u'cloth',
#   u'improv',
#   u'ahead',
#   u'alway',
#   u'thank'],
#  [u'start-up',
#   u'famili',
#   u'incom',
#   u'condit',
#   u'credit',
#   u'credo',
#   u'poor',
#   u'request',
#   u'live',
#   u'initi',
#   u'low',
#   u'local',
#   u'loan',
#   u'busi',
#   u'joint',
#   u'product',
#   u'new',
#   u'approv',
#   u'rural',
#   u'program',
#   u'access',
#   u'kiva',
#   u'reject',
#   u'framework',
#   u'regard'],
#  [u'hekima',
#   u'entrepreneur',
#   u'busi',
#   u'husband',
#   u'children',
#   u'thank',
#   u'client',
#   u'mother',
#   u'new',
#   u'school',
#   u'loan',
#   u'exclud',
#   u'fund',
#   u'bank',
#   u'start',
#   u'educ',
#   u'year',
#   u'support',
#   u'women',
#   u'tradit',
#   u'receiv',
#   u'shoe',
#   u'build',
#   u'cloth',
#   u'action']]

# %%
# what're the topics for those top loans?
desc_transformed = nmf_desc.transform(tfidf_desc)[:20]

# %%
for t in range(len(topic_words)):
    print("Topic {}: {}".format(t, ', '.join([w.encode('utf-8') for w in topic_words[t][:15]])))
# Out:
# Topic 0: busi, hope, shop, profit, open, custom, week, good, receiv, loan, oper, age, year, expand, develop
# Topic 1: pro, mujer, sale, sell, member, like, busi, invit, board, communal, cycl, institut, join, ask, benefit
# Topic 2: acr, farmer, fund, harvest, group, seed, repres, leader, fertil, ¼, farm, season, kiva, sorghum, save
# Topic 3: loan, tanzania, tujijeng, hold, account, pay, abl, share, daili, month, paid, previous, total, use, profit.thi
# Topic 4: year, children, school, turam, old, group, capit, rice, buy, marri, sell, age, larg, increas, loan
# Topic 5: villag, farm, husband, cultiv, agricultur, famili, incom, cow, livestock, pig, help, son, cattl, live, fertil
# Topic 6: p, br, /p, translat, /strong, strong, volunt, spanish, member, kiva, group, sell, product, food, sale
# Topic 7: esperanza, busi, group, coordin, invest, use, loan, excit, dominican, plan, structur, simpl, water, home, cloth
# Topic 8: banc, group, villageoi, women, right, franc, hand, rais, creat, villag, photo, stand, activ, mother, 's
# Topic 9: hous, mongolia, live, mnt, son, wife, ulaanbaatar, husband, citi, materi, insul, build, famili, year, daughter
# Topic 10: iraq, sew, iraqi, client, capac, intern, unabl, microfin, relief, group, repay, individu, machin, loan, borrow
# Topic 11: bank, communal, member, cusco, sell, anim, work, citi, pig, provinc, rais, chicken, guinea, locat, belong
# Topic 12: veri, help, work, women, becaus, continu, group, abl, custom, sell, want, famili, make, committe, order
# Topic 13: start-up, famili, incom, condit, credit, credo, poor, request, live, initi, low, local, loan, busi, joint
# Topic 14: hekima, entrepreneur, busi, husband, children, thank, client, mother, new, school, loan, exclud, fund, bank, start

# %%
concise_topics_desc = ['[business] open a store and payback',
                       '[business] formal business needs investment',
                       '[farming] preparing for the season',
                       'Tujijenge in Tanzania',
                       '[family] send children to school',
                       '[farming] farming and livestock in a village',
                       'With translation',
                       '[business] Latin America borrowing for business',
                       '[business] women group, small business',
                       '[family]Central Asians supporting family',
                       'Iraq',
                       '[farming] community buys and sells livestocks',
                       '[business] women group, small business',
                       '[business] initial funding to start business',
                       '[business] entrepreneur starts business to help children']

# %%
for i in range(len(desc_transformed)):
    top_topics = np.argsort(desc_transformed[i,:])[::-1][0]
    print("{}: {}".format(i+1, concise_topics_desc[top_topics]))
# Out:
# 1: [business] Latin America borrowing for business
# 2: [business] initial funding to start business
# 3: [farming] preparing for the season
# 4: [business] open a store and payback
# 5: [farming] preparing for the season
# 6: [business] women group, small business
# 7: [farming] preparing for the season
# 8: [business] initial funding to start business
# 9: [farming] preparing for the season
# 10: [farming] preparing for the season
# 11: [business] Latin America borrowing for business
# 12: [business] open a store and payback
# 13: [business] women group, small business
# 14: Iraq
# 15: [business] women group, small business
# 16: With translation
# 17: [business] women group, small business
# 18: [business] women group, small business
# 19: [business] open a store and payback
# 20: [business] women group, small business

# %% [markdown]
# ##'Use' topics

# %%
# create tfidf of descriptions
use = df.sort('lender_count', ascending=False)['use'].values
vec_use = get_vectorizer(use)
tfidf_use = vec_use.transform(use).toarray()

# %%
# run NMF and get topics
topic_words_use = []
nmf_use = NMF(n_components=15).fit(tfidf_use)
feature_names_use = vec_use.get_feature_names()

# %%
for topic in nmf_use.components_:
    word_idx = np.argsort(topic)[::-1][0:num_top_words]
    topic_words_use.append([feature_names_use[i] for i in word_idx])

# %%
topic_words_use
# Out:
# [[u'cloth',
#   u'shoe',
#   u'buy',
#   u'cosmet',
#   u'use',
#   u'bale',
#   u"'s",
#   u'new',
#   u'women',
#   u'season',
#   u'second-hand',
#   u'winter',
#   u'children',
#   u'perfum',
#   u'accessori',
#   u'sale',
#   u'bundl',
#   u'miscellan',
#   u'pant',
#   u'men'],
#  [u'purchas',
#   u'materi',
#   u'product',
#   u'build',
#   u'equip',
#   u'inventori',
#   u'addit',
#   u'insul',
#   u'suppli',
#   u'raw',
#   u'make',
#   u'new',
#   u'pesticid',
#   u'bulk',
#   u'cow',
#   u'construct',
#   u'machin',
#   u'car',
#   u'hous',
#   u'thread'],
#  [u'capit',
#   u'work',
#   u'oper',
#   u'increas',
#   u'larg',
#   u'quantiti',
#   u'order',
#   u'earn',
#   u'respect',
#   u'area',
#   u'reinforc',
#   u'make',
#   u'lot',
#   u'money',
#   u'banana',
#   u'use',
#   u'profit',
#   u'mani',
#   u'addit',
#   u'expens'],
#  [u'buy',
#   u'fabric',
#   u'suppli',
#   u'product',
#   u'materi',
#   u'wholesal',
#   u'thread',
#   u'make',
#   u'wool',
#   u'sew',
#   u'cosmet',
#   u'machin',
#   u'ingredi',
#   u'shoe',
#   u'beauti',
#   u'groceri',
#   u'food',
#   u'cattl',
#   u'salon',
#   u'bulk'],
#  [u'busi',
#   u'invest',
#   u'new',
#   u'expand',
#   u'start',
#   u'suppli',
#   u'inventori',
#   u'respect',
#   u'equip',
#   u'grow',
#   u'market',
#   u'machin',
#   u'improv',
#   u'small',
#   u'restock',
#   u'sew',
#   u'tailor',
#   u'develop',
#   u'organ',
#   u'open'],
#  [u'merchandis',
#   u'store',
#   u'buy',
#   u'general',
#   u'groceri',
#   u'raw',
#   u'invest',
#   u'season',
#   u'restock',
#   u'like',
#   u'milk',
#   u'christma',
#   u'purchas',
#   u'various',
#   u'special',
#   u'hardwar',
#   u'winter',
#   u'women',
#   u'person',
#   u'catalog'],
#  [u'veget',
#   u'fruit',
#   u'meat',
#   u'buy',
#   u'season',
#   u'condiment',
#   u'bulk',
#   u'oil',
#   u'stall',
#   u'wholesal',
#   u'organ',
#   u'varieti',
#   u'sale',
#   u'chicken',
#   u'charcoal',
#   u'tomato',
#   u'seed',
#   u'plant',
#   u'green',
#   u'orang'],
#  [u'resal',
#   u'larg',
#   u'shoe',
#   u'quantiti',
#   u'produc',
#   u'buy',
#   u'banana',
#   u'bean',
#   u'pair',
#   u'earn',
#   u'item',
#   u'fatten',
#   u'good',
#   u'fish',
#   u'beer',
#   u'palm',
#   u'increas',
#   u'mani',
#   u'profit',
#   u'goat'],
#  [u'pay',
#   u'fee',
#   u'school',
#   u'children',
#   u'tuition',
#   u"'s",
#   u'educ',
#   u'cow',
#   u'univers',
#   u'forag',
#   u'cost',
#   u'rent',
#   u'livestock',
#   u'shop',
#   u'mainten',
#   u'son',
#   u'expens',
#   u'renov',
#   u'labor',
#   u'studi'],
#  [u'chicken',
#   u'feed',
#   u'pig',
#   u'anim',
#   u'guinea',
#   u'buy',
#   u'chick',
#   u'livestock',
#   u'forag',
#   u'piglet',
#   u'food',
#   u'rais',
#   u'duck',
#   u'vitamin',
#   u'balanc',
#   u'sheep',
#   u'beef',
#   u'cattl',
#   u'poultri',
#   u'hen'],
#  [u'rice',
#   u'sugar',
#   u'oil',
#   u'flour',
#   u'bean',
#   u'milk',
#   u'cook',
#   u'noodl',
#   u'sack',
#   u'buy',
#   u'soap',
#   u'meat',
#   u'food',
#   u'salt',
#   u'egg',
#   u'bag',
#   u'item',
#   u'good',
#   u'palm',
#   u'potato'],
#  [u'resel',
#   u'fish',
#   u'profit',
#   u'larg',
#   u'charcoal',
#   u'earn',
#   u'quantiti',
#   u'sack',
#   u'buy',
#   u'increas',
#   u'bag',
#   u'net',
#   u'banana',
#   u'order',
#   u'dri',
#   u'fresh',
#   u'retail',
#   u'salt',
#   u'smoke',
#   u'bean'],
#  [u'fertil',
#   u'seed',
#   u'millet',
#   u'maiz',
#   u'sorghum',
#   u'hybrid',
#   u'cultiv',
#   u'pesticid',
#   u'access',
#   u'harvest',
#   u'cost',
#   u'farmer',
#   u'effici',
#   u'gain',
#   u'cost-effici',
#   u'kenyan',
#   u'farm',
#   u'provid',
#   u'support',
#   u'fuel'],
#  [u'sell',
#   u'food',
#   u'buy',
#   u'fish',
#   u'custom',
#   u'product',
#   u'rais',
#   u'start',
#   u'item',
#   u'charcoal',
#   u'drink',
#   u'addit',
#   u'banana',
#   u'milk',
#   u'produc',
#   u'chicken',
#   u'good',
#   u'groceri',
#   u'shoe',
#   u'juic'],
#  [u'stock',
#   u'increas',
#   u'store',
#   u'inventori',
#   u'groceri',
#   u'food',
#   u'shop',
#   u'item',
#   u'good',
#   u'profit',
#   u'sale',
#   u'restock',
#   u'retail',
#   u'product',
#   u'order',
#   u'add',
#   u'open',
#   u'drink',
#   u'general',
#   u'custom']]

# %%
# what're the topics for those top loans?
use_transformed = nmf_use.transform(tfidf_use)[:20]

# %%
for t in range(len(topic_words_use)):
    print("Topic {}: {}".format(t, ', '.join([w.encode('utf-8') for w in topic_words_use[t][:15]])))
# Out:
# Topic 0: cloth, shoe, buy, cosmet, use, bale, 's, new, women, season, second-hand, winter, children, perfum, accessori
# Topic 1: purchas, materi, product, build, equip, inventori, addit, insul, suppli, raw, make, new, pesticid, bulk, cow
# Topic 2: capit, work, oper, increas, larg, quantiti, order, earn, respect, area, reinforc, make, lot, money, banana
# Topic 3: buy, fabric, suppli, product, materi, wholesal, thread, make, wool, sew, cosmet, machin, ingredi, shoe, beauti
# Topic 4: busi, invest, new, expand, start, suppli, inventori, respect, equip, grow, market, machin, improv, small, restock
# Topic 5: merchandis, store, buy, general, groceri, raw, invest, season, restock, like, milk, christma, purchas, various, special
# Topic 6: veget, fruit, meat, buy, season, condiment, bulk, oil, stall, wholesal, organ, varieti, sale, chicken, charcoal
# Topic 7: resal, larg, shoe, quantiti, produc, buy, banana, bean, pair, earn, item, fatten, good, fish, beer
# Topic 8: pay, fee, school, children, tuition, 's, educ, cow, univers, forag, cost, rent, livestock, shop, mainten
# Topic 9: chicken, feed, pig, anim, guinea, buy, chick, livestock, forag, piglet, food, rais, duck, vitamin, balanc
# Topic 10: rice, sugar, oil, flour, bean, milk, cook, noodl, sack, buy, soap, meat, food, salt, egg
# Topic 11: resel, fish, profit, larg, charcoal, earn, quantiti, sack, buy, increas, bag, net, banana, order, dri
# Topic 12: fertil, seed, millet, maiz, sorghum, hybrid, cultiv, pesticid, access, harvest, cost, farmer, effici, gain, cost-effici
# Topic 13: sell, food, buy, fish, custom, product, rais, start, item, charcoal, drink, addit, banana, milk, produc
# Topic 14: stock, increas, store, inventori, groceri, food, shop, item, good, profit, sale, restock, retail, product, order

# %%
concise_topic_use = ['[family]buy clothes for women and children',
                     '[business]buy materials to make products',
                     '[business]expanding business',
                     '[living]buy materials to make fabric products to sell',
                     '[business]expanding business',
                     '[business]restock inventories',
                     '[business]buy/sell seasonal food products',
                     '[business]resale larget quantity of products',
                     '[family]pay for school',
                     '[living]raise livestock',
                     '[living]groceries for living',
                     '[business]resale larget quantity of products',
                     '[living]fertilize and farming operations',
                     '[living]selling food product',
                     '[business]grocery and retail business']

# %%
for i in range(len(use_transformed)):
    top_topics = np.argsort(use_transformed[i,:])[::-1][0]
    print("{}: {}".format(i, concise_topic_use[top_topics]))
# Out:
# 0: [living]fertilize and farming operations
# 1: [living]selling food product
# 2: [living]selling food product
# 3: [business]expanding business
# 4: [living]selling food product
# 5: [living]selling food product
# 6: [living]selling food product
# 7: [family]pay for school
# 8: [business]expanding business
# 9: [living]selling food product
# 10: [business]buy materials to make products
# 11: [business]grocery and retail business
# 12: [living]selling food product
# 13: [family]pay for school
# 14: [living]buy materials to make fabric products to sell
# 15: [living]buy materials to make fabric products to sell
# 16: [living]buy materials to make fabric products to sell
# 17: [living]buy materials to make fabric products to sell
# 18: [living]buy materials to make fabric products to sell
# 19: [family]pay for school

# %%
lenders = pd.read_csv('data/lenders.csv')
